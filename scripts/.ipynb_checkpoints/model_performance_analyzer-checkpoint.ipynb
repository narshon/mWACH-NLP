# %% [markdown]
# # Model Performance Analyzer

# %% [markdown]
# We review several models with respect to their performance outputs for a simple classification problem:
# Given a message sent to a participant, what is the probability of a getting back a response?
# The following models have been tested in this notebook and their accuracy and roc_auc_scores recorded and plotted for comparisons.
#     1. Logistic regression using edd, language, char and words
#     2. Gradient Boosting classifier using edd, language, char and words
#     3. Logistic regression using bow only
#     4. Gradient Boosting classifier using bow only
#     5. Logistic regression using bow, edd, & language
#     6. Gradient Boosting classifier using bow, edd, & language
#     7. Logistic regression using bi-grams only
#     8. Gradient Boosting classifier using bi-grams only
#     9. Logistic regression using bi-grams, edd, & language
#     10. Gradient Boosting classifier using bi-grams, edd, & language
#     11. Logistic regression using word2vec only
#     12. Gradient boosting using word2vec only
#     13. Logistic regression using word2vec, edd, & language only
#     14. Gradient boosting using word2vec, edd, & language only
#     15. Logistic regression using doc2vec only
#     16. Gradient boosting using doc2vec only
#     17. Logistic regression using doc2vec, edd, & language only
#     18. Gradient boosting using doc2vec, edd, & language only

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model
import nltk as nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.model_selection import RepeatedKFold
import sklearn.ensemble
import statistics
from nltk import sent_tokenize, word_tokenize
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from sklearn.metrics import classification_report
pd.set_option('display.max_rows', 4)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
messages_df = pd.read_excel("C:/Users/user/UW/keshet - mwach_interaction/SMSdata/mwachNeo/allSMSdatabase/messages_export_2019-03-05.xlsx")
messages_df.shape
# Out:
# (59506, 19)

# %%
# Remove nurse responses from these messages.
messages_df = messages_df[messages_df['sent_by']!='nurse']
messages_df.shape
# Out:
# (45971, 19)

# %%
messages_df
# Out:
#          mid  pid  day               timestamp                     auto  \
# 0        808   15  Tue 2017-12-05 06:36:59.614  signup.two-way.normal.0
# 1        859   15  Tue 2017-12-05 06:55:45.982                      NaN
# ...      ...  ...  ...                     ...                      ...
# 59503  56257  800  Wed 2018-07-11 17:05:27.065    edd.two-way.normal.10
# 59504  56843  800  Sun 2018-07-15 17:05:23.401    edd.two-way.normal.14
#
#       external delta_human        delta  delta_last  study_wk    edd_wk  \
# 0      Success         NaN          NaN         NaN  0.000000 -9.000000
# 1          NaN        18m   1126.367329         NaN  0.000000 -9.000000
# ...        ...         ...          ...         ...       ...       ...
# 59503   Failed         NaN          NaN         NaN  8.142857  1.428571
# 59504   Failed         NaN          NaN         NaN  8.714286  2.000000
#
#        chars  words       topic  related      sent_by language  \
# 0        250     42         NaN      NaN       system  swahili
# 1         30      4  validation      1.0  participant  english
# ...      ...    ...         ...      ...          ...      ...
# 59503    168     24  41.5 weeks      NaN       system  swahili
# 59504    252     41    42 weeks      NaN       system  swahili
#
#                                               translated  \
# 0      Welcome to Mobile WACh NEO! Good job coming in...
# 1                                                    NaN
# ...                                                  ...
# 59503  {name}, this is {nurse} from {clinic}. Have yo...
# 59504  {name}, this is {nurse} from {clinic} Bad swel...
#
#                                                 original
# 0      Karibu kwa Mobile WACh NEO. Kazi nzuri kwa kuj...
# 1                         Validation Code Correct: 13514
# ...                                                  ...
# 59503  Linet, huyu ni Mercy kutoka Rachuonyo. Umejifu...
# 59504  Linet, huyu ni Mercy kutoka Rachuonyo. kufura ...
#
# [45971 rows x 19 columns]

# %%
messages_df['system_msg'] = (messages_df['sent_by']=='system')
print("Number of System Messages: ", messages_df['system_msg'].sum())
# Out:
# Number of System Messages:  26021

# %%
#We need to know number of responses each system message received. --- we will come back later to remove nurse messages
messages_df['msg_group'] = messages_df.system_msg.cumsum()
messages_df.msg_group.value_counts()
# Out:
# 7115     114
# 24446     23
#         ...
# 9385       1
# 2047       1
# Name: msg_group, Length: 26021, dtype: int64

# %%
#Our responses vector is all those messages with a value count of more than 1
response = (messages_df.msg_group.value_counts() > 1)

# %%
systemMessagesDF = messages_df[messages_df.sent_by == "system"]
systemMessagesDF = systemMessagesDF.set_index('msg_group')
systemMessagesDF['response'] = response
systemMessagesDF
# Out:
#              mid  pid  day               timestamp                     auto  \
# msg_group
# 1            808   15  Tue 2017-12-05 06:36:59.614  signup.two-way.normal.0
# 2           1926   15  Tue 2017-12-12 17:05:02.999   edd.two-way.normal.-56
# ...          ...  ...  ...                     ...                      ...
# 26020      56257  800  Wed 2018-07-11 17:05:27.065    edd.two-way.normal.10
# 26021      56843  800  Sun 2018-07-15 17:05:23.401    edd.two-way.normal.14
#
#           external delta_human  delta  delta_last  study_wk  ...  chars  \
# msg_group                                                    ...
# 1          Success         NaN    NaN         NaN  0.000000  ...    250
# 2          Success         NaN    NaN         NaN  1.000000  ...    428
# ...            ...         ...    ...         ...       ...  ...    ...
# 26020       Failed         NaN    NaN         NaN  8.142857  ...    168
# 26021       Failed         NaN    NaN         NaN  8.714286  ...    252
#
#            words       topic related  sent_by language  \
# msg_group
# 1             42         NaN     NaN   system  swahili
# 2             65    32 weeks     NaN   system  swahili
# ...          ...         ...     ...      ...      ...
# 26020         24  41.5 weeks     NaN   system  swahili
# 26021         41    42 weeks     NaN   system  swahili
#
#                                                   translated  \
# msg_group
# 1          Welcome to Mobile WACh NEO! Good job coming in...
# 2          {name}, this is {nurse} from {clinic}. Sometim...
# ...                                                      ...
# 26020      {name}, this is {nurse} from {clinic}. Have yo...
# 26021      {name}, this is {nurse} from {clinic} Bad swel...
#
#                                                     original system_msg  \
# msg_group
# 1          Karibu kwa Mobile WACh NEO. Kazi nzuri kwa kuj...       True
# 2          Mama Lucas, huyu ni Brenda kutoka Mathare. Wak...       True
# ...                                                      ...        ...
# 26020      Linet, huyu ni Mercy kutoka Rachuonyo. Umejifu...       True
# 26021      Linet, huyu ni Mercy kutoka Rachuonyo. kufura ...       True
#
#            response
# msg_group
# 1              True
# 2              True
# ...             ...
# 26020         False
# 26021         False
#
# [26021 rows x 21 columns]

# %%
# %time
#calculate past response rate of system message (did this participant respond to the last message?)
#let loop through the messages and check current participant has a previous system message with a response
#for mid, pid, has_response from systemMesaagesDF:
def past_response(mid2, pid2):
    has_prev_response = 0
    #get prev system message to this participant
    # last system message from this participant before the current one
    last_msg = systemMessagesDF[(systemMessagesDF.pid == pid2) & (systemMessagesDF.mid < mid2) ].tail(1) 
    
    if(len(last_msg) > 0):
        return last_msg.iloc[0]['response']
    else:
        return False
    
    
#past_response(808, 15)
systemMessagesDF['past_response'] = systemMessagesDF.apply(lambda row: past_response(row.mid, row['pid']), axis=1)
# Out:
# Wall time: 0 ns

# %%
systemMessagesDF
# Out:
#              mid  pid  day               timestamp                     auto  \
# msg_group
# 1            808   15  Tue 2017-12-05 06:36:59.614  signup.two-way.normal.0
# 2           1926   15  Tue 2017-12-12 17:05:02.999   edd.two-way.normal.-56
# ...          ...  ...  ...                     ...                      ...
# 26020      56257  800  Wed 2018-07-11 17:05:27.065    edd.two-way.normal.10
# 26021      56843  800  Sun 2018-07-15 17:05:23.401    edd.two-way.normal.14
#
#           external delta_human  delta  delta_last  study_wk  ...  words  \
# msg_group                                                    ...
# 1          Success         NaN    NaN         NaN  0.000000  ...     42
# 2          Success         NaN    NaN         NaN  1.000000  ...     65
# ...            ...         ...    ...         ...       ...  ...    ...
# 26020       Failed         NaN    NaN         NaN  8.142857  ...     24
# 26021       Failed         NaN    NaN         NaN  8.714286  ...     41
#
#                 topic  related sent_by  language  \
# msg_group
# 1                 NaN      NaN  system   swahili
# 2            32 weeks      NaN  system   swahili
# ...               ...      ...     ...       ...
# 26020      41.5 weeks      NaN  system   swahili
# 26021        42 weeks      NaN  system   swahili
#
#                                                   translated  \
# msg_group
# 1          Welcome to Mobile WACh NEO! Good job coming in...
# 2          {name}, this is {nurse} from {clinic}. Sometim...
# ...                                                      ...
# 26020      {name}, this is {nurse} from {clinic}. Have yo...
# 26021      {name}, this is {nurse} from {clinic} Bad swel...
#
#                                                     original system_msg  \
# msg_group
# 1          Karibu kwa Mobile WACh NEO. Kazi nzuri kwa kuj...       True
# 2          Mama Lucas, huyu ni Brenda kutoka Mathare. Wak...       True
# ...                                                      ...        ...
# 26020      Linet, huyu ni Mercy kutoka Rachuonyo. Umejifu...       True
# 26021      Linet, huyu ni Mercy kutoka Rachuonyo. kufura ...       True
#
#           response  past_response
# msg_group
# 1             True          False
# 2             True           True
# ...            ...            ...
# 26020        False          False
# 26021        False          False
#
# [26021 rows x 22 columns]

# %%
#check for native langauge.
systemMessagesDF['native_langauge'] = np.where(systemMessagesDF['language'] != 'english', True, False)
systemMessagesDF.loc[:,['language','native_langauge'] ]
# Out:
#           language  native_langauge
# msg_group
# 1          swahili             True
# 2          swahili             True
# ...            ...              ...
# 26020      swahili             True
# 26021      swahili             True
#
# [26021 rows x 2 columns]

# %%
#Allocate features now.
systemMessagesDF['swahili'] = systemMessagesDF.language == 'swahili'
systemMessagesDF['english'] = systemMessagesDF.language == 'english'
systemMessagesDF['luo'] = systemMessagesDF.language == 'luo'
systemMessagesDF['delivery_status'] = systemMessagesDF.external == 'Success'

# %%
#Let's now filter the columns and convert them to float.
X = systemMessagesDF.filter(['edd_wk','study_wk', 'past_response', 'native_langauge', 'swahili', 'english', 'luo','delivery_status']).astype(float)
y = systemMessagesDF.response.astype(float)
X
# Out:
#              edd_wk  study_wk  past_response  native_langauge  swahili  \
# msg_group
# 1         -9.000000  0.000000            0.0              1.0      1.0
# 2         -8.000000  1.000000            1.0              1.0      1.0
# ...             ...       ...            ...              ...      ...
# 26020      1.428571  8.142857            0.0              1.0      1.0
# 26021      2.000000  8.714286            0.0              1.0      1.0
#
#            english  luo  delivery_status
# msg_group
# 1              0.0  0.0              1.0
# 2              0.0  0.0              1.0
# ...            ...  ...              ...
# 26020          0.0  0.0              0.0
# 26021          0.0  0.0              0.0
#
# [26021 rows x 8 columns]

# %%
# Normalize X
# from sklearn.preprocessing import normalize as normalize
# X_norm = normalize(X, norm='l2', axis=0, copy=False, return_norm=False)
# X_norm

# %%
features_list = ['edd_wk','study_wk', 'past_response', 'native_langauge','delivery_status', 'swahili', 'english', 'luo']
X = systemMessagesDF.filter(features_list).astype(float)
X
# Out:
#              edd_wk  study_wk  past_response  native_langauge  \
# msg_group
# 1         -9.000000  0.000000            0.0              1.0
# 2         -8.000000  1.000000            1.0              1.0
# ...             ...       ...            ...              ...
# 26020      1.428571  8.142857            0.0              1.0
# 26021      2.000000  8.714286            0.0              1.0
#
#            delivery_status  swahili  english  luo
# msg_group
# 1                      1.0      1.0      0.0  0.0
# 2                      1.0      1.0      0.0  0.0
# ...                    ...      ...      ...  ...
# 26020                  0.0      1.0      0.0  0.0
# 26021                  0.0      1.0      0.0  0.0
#
# [26021 rows x 8 columns]

# %%
systemMessagesDF['translated'].fillna(systemMessagesDF.original, inplace=True)
null_ = systemMessagesDF.loc[systemMessagesDF['translated'].isnull()]
#systemMessagesDF.to_csv("no_nulls.csv")
#verifying that we don't have missing translations
null_
# Out:
# Empty DataFrame
# Columns: [mid, pid, day, timestamp, auto, external, delta_human, delta, delta_last, study_wk, edd_wk, chars, words, topic, related, sent_by, language, translated, original, system_msg, response, past_response, native_langauge, swahili, english, luo, delivery_status]
# Index: []
#
# [0 rows x 27 columns]

# %%
#Lets create our text corpus
X_text = systemMessagesDF.translated.astype('str')
corpus = X_text.values
corpus
# Out:
# array(["Welcome to Mobile WACh NEO! Good job coming in for your visit! You will receive weekly SMS to help support you during pregnancy and during the first months of your baby's life. Please SMS back and tell us any questions or concerns you have.",
#        '{name}, this is {nurse} from {clinic}. Sometimes problems arise during labour and delivery, like bleeding or fits, which require skilled health workers, medications and equipment to treat. Without that treatment, the mother and baby could die. Therefore it is safest to deliver in a facility that can manage these and other problems. How will you arrive at the facility?',
#        '{name}, this is {nurse} from {clinic} Bad swelling of hands and face or a bad headache are signs of a problem. Ask your family to take you to the clinic if they see this. Have you had any swelling or headaches during pregnancy? Are they getting worse?',
#        ...,
#        '{name}, this is {nurse} from {clinic}. Breastfeeding a baby immediately after birth helps the milk come. The first yellow sticky milk has many vitamins & protects the baby from illness. Milk has all the water the baby needs, avoid other liquids. Are you planning to breastfeed?',
#        '{name}, this is {nurse} from {clinic}. Have you had your baby? We are here for you. Please let us know as soon as you deliver so we can assist you after the baby arrives.',
#        '{name}, this is {nurse} from {clinic} Bad swelling of hands and face or a bad headache are signs of a problem. Ask your family to take you to the clinic if they see this. Have you had any swelling or headaches during pregnancy? Are they getting worse?'],
#       dtype=object)

# %%
from nltk.corpus import stopwords
from string import punctuation
stopwords_en = set(stopwords.words('english'))
stopwords_en_withpunct = stopwords_en.union(set(punctuation))

# %%
#Swahili stop words
stopwords_sw = set(["akasema","alikuwa","alisema","baada","basi","bila","cha","chini","hadi","hapo","hata","hivyo","hiyo","huku","huo","ili","ilikuwa","juu","kama","karibu","katika","kila","kima","kisha","kubwa","kutoka","kuwa","kwa","kwamba","kwenda","kwenye","la","lakini","mara","mdogo","mimi","mkubwa","mmoja","moja","muda","mwenye","na","naye","ndani","ng","ni","nini","nonkungu","pamoja","pia","sana","sasa","sauti","tafadhali","tena","tu","vile","wa","wakati","wake","walikuwa","wao","watu","wengine","wote","ya","yake","yangu","yao","yeye","yule","za","zaidi","zake"])
#More english stopwords
stopwords_en_more = set(["a","a's","able","about","above","according","accordingly","across","actually","after",
                         "afterwards","again","against","ain't","all","allow","allows","almost","alone","along","already",
                         "also","although","always","am","among","amongst","an","and","another","any","anybody","anyhow",
                         "anyone","anything","anyway","anyways","anywhere","apart","appear","appreciate","appropriate","are","aren't","around","as","aside","ask","asking","associated","at","available","away","awfully","b","be","became","because","become","becomes","becoming","been","before","beforehand","behind","being","believe","below","beside","besides","best","better","between","beyond","both","brief","but","by","c","c'mon","c's","came","can","can't","cannot","cant","cause","causes","certain","certainly","changes","clearly","co","com","come","comes","concerning","consequently","consider","considering","contain","containing","contains","corresponding","could","couldn't","course","currently","d","definitely","described","despite","did","didn't","different","do","does","doesn't","doing","don't","done","down","downwards","during","e","each","edu","eg","eight","either","else","elsewhere","enough","entirely","especially","et","etc","even","ever","every","everybody","everyone","everything","everywhere","ex","exactly","example","except","f","far","few","fifth","first","five","followed","following","follows","for","former","formerly","forth","four","from","further","furthermore","g","get","gets","getting","given","gives","go","goes","going","gone","got","gotten","greetings","h","had","hadn't","happens","hardly","has","hasn't","have","haven't","having","he",
                         "he's","hello","help","hence","her","here","here's","hereafter","hereby","herein","hereupon","hers","herself","hi","him","himself","his","hither","hopefully","how","howbeit","however","i","i'd","i'll","i'm","i've","ie","if","ignored","immediate","in","inasmuch","inc","indeed","indicate","indicated","indicates","inner","insofar","instead","into","inward","is","isn't","it","it'd","it'll","it's","its","itself","j","just","k","keep","keeps","kept","know","known","knows","l","last","lately","later","latter","latterly","least","less","lest","let","let's","like","liked","likely","little","look","looking","looks","ltd","m","mainly","many","may","maybe","me","mean","meanwhile","merely","might","more","moreover","most","mostly","much","must","my","myself","n","name","namely","nd","near","nearly","necessary","need","needs","neither","never","nevertheless","new","next","nine","no","nobody","non","none","noone","nor","normally","not","nothing","novel","now","nowhere","o","obviously","of","off","often","oh","ok","okay","old","on","once","one","ones","only","onto","or","other","others","otherwise","ought","our","ours","ourselves","out","outside","over","overall","own","p","particular","particularly","per","perhaps","placed","please","plus","possible","presumably","probably","provides","q","que","quite","qv","r","rather","rd","re","really","reasonably","regarding","regardless","regards","relatively","respectively","right","s","said","same","saw","say","saying","says","second","secondly","see","seeing","seem","seemed","seeming","seems","seen","self","selves","sensible","sent","serious","seriously","seven","several","shall","she","should","shouldn't","since","six","so","some","somebody","somehow","someone","something","sometime","sometimes","somewhat","somewhere","soon","sorry","specified","specify","specifying","still","sub","such","sup","sure","t","t's","take","taken","tell","tends","th","than","thank","thanks","thanx","that","that's","thats","the","their","theirs","them","themselves","then","thence","there","there's","thereafter","thereby","therefore","therein","theres","thereupon","these","they","they'd","they'll","they're","they've","think","third","this","thorough","thoroughly","those","though","three","through","throughout","thru","thus","to","together","too","took","toward","towards","tried","tries","truly","try","trying","twice","two","u","un","under","unfortunately","unless","unlikely","until","unto","up","upon","us","use","used","useful","uses","using","usually","uucp","v","value","various","very","via","viz","vs","w","want","wants","was","wasn't","way","we","we'd","we'll","we're","we've","welcome","well","went","were","weren't","what","what's","whatever","when","whence","whenever","where","where's","whereafter","whereas","whereby","wherein","whereupon","wherever","whether","which","while","whither","who","who's","whoever","whole","whom","whose","why","will","willing","wish","with","within","without","won't","wonder","would","wouldn't","x","y","yes","yet","you",
                         "you'd","you'll","you're","you've","your","yours","yourself","yourselves","z","zero"])
stopwords_translated = set(["nurse", "clinic","name"]) # removing the default salutation for translated messages
stopwords_en_more = stopwords_en_more.union(stopwords_translated)
stopwords_en_more = stopwords_en_more.union(stopwords_sw)
stopwords_all = stopwords_en_withpunct.union(stopwords_en_more)
print(stopwords_all)
# Out:
# {'hi', 'selves', 'thence', 'gives', 'yeye', 'under', 'baada', 'considering', 'looks', 'afterwards', 'sauti', 'better', '[', 'kutoka', 'wonder', 'took', 'might', 'about', 'very', 'la', 'hence', 'awfully', 'katika', 'mwenye', 'causes', "we'll", 'whom', 'uucp', 'are', 'indeed', 'across', 'away', 'whenever', 'ilikuwa', 'with', "needn't", 'kept', 'follows', 'am', 'said', 'different', '?', 'towards', 'unless', 'kila', 'somewhere', "should've", 'forth', 'an', 'already', 'sent', 'none', 'unto', 'his', 'some', 'after', 'pamoja', 'always', 'wake', 'thoroughly', 'qv', 'any', 'followed', '!', 'wherein', 'kwenye', 'little', 'ili', 'whoever', 'associated', 'she', 'indicated', "c'mon", 'watu', 'seem', 'appropriate', 'inner', 'thanx', "you'll", 'wote', 'thus', 'mainly', 'downwards', "won't", 'be', 'alisema', 'in', 'okay', 'themselves', 'many', 'anyways', 'containing', 'though', 'use', 'before', 'tried', 'how', 'welcome', 'which', 'own', 'seven', 'thank', 'because', 'tends', 'gone', 'used', 'few', 'thats', "we've", 'at', 'both', 'ain', 'described', 'also', 'someone', 'probably', 'your', 'becoming', 'believe', 'ok', 'since', 'ie', 'such', 'akasema', 'ought', 'ltd', 'last', 'e', 'however', 'what', 'meanwhile', 'sana', 'huku', 'herein', 'quite', 'regards', 'between', 'those', 'now', 'getting', 'happens', 'keeps', 'were', 'least', 'most', 'appreciate', 'ours', 'otherwise', 'hadn', 'itself', 'that', 'thanks', 'and', 'please', 'four', 'a', 'furthermore', 'nd', 'has', 'apart', 'perhaps', ')', 'pia', 't', "that'll", 'immediate', 'nothing', 'walikuwa', 'was', 'become', '=', ']', 'respectively', "let's", '*', 'up', 're', 'namely', 'first', 'uses', 'fifth', 'seriously', 'allow', 'doing', 'wao', 'yes', 'v', 'especially', "doesn't", '<', 'b', 'need', 'ni', 'necessary', "hasn't", 'f', "ain't", 'until', 'herself', 'five', 'liked', 'ourselves', 'thereafter', 'along', 'y', 'whereupon', 'only', 'cannot', '$', 'comes', 'needs', 'wa', 'w', 'hopefully', 'else', 'keep', 'whither', "mightn't", 'et', 'hasn', 'n', 'clearly', '~', 'no', 'sasa', 'to', "there's", 'toward', 'various', 'truly', '>', 'onto', 'tries', 'placed', 'edu', '/', 'available', 'regarding', 'serious', 'ignored', 'saying', "shouldn't", 'old', 'go', 'howbeit', 'this', 'may', 'everywhere', 'get', 'consider', 'zaidi', '+', 'these', 'don', 'elsewhere', 'aren', 'seen', 'basi', 'hereafter', 'r', 'kwenda', 'seeing', 'willing', 'around', 'or', 'did', 'kwamba', 'needn', 'but', 'doesn', '|', 'somebody', 'whence', 'above', 'from', 'becomes', 'zake', 'name', 'our', 'have', "isn't", 'kisha', 'amongst', 'too', 'want', 'brief', '(', 'third', 'over', 'try', 'co', 'latter', 'chini', 'accordingly', '^', 'according', 'rd', 'will', 'must', 've', 'should', '\\', "i'm", 'hapo', 'three', 'com', 'll', 'given', 'lest', 'useful', 'on', '&', 'likely', 'hivyo', 'mightn', 'beside', "they'd", 'taken', 'mean', 'wengine', 'somewhat', 'kubwa', 'corresponding', 'further', 'somehow', 'example', 'seemed', 'sensible', 'their', 'vile', 'particular', 'per', 'just', "where's", 'ex', 'tena', 'everything', 'unlikely', 'changes', 'oh', 'others', 'say', 'here', 'latterly', 'mmoja', 'outside', 'haven', 'as', 'wakati', 'na', 'hers', "couldn't", 'wasn', 'so', 'something', 'greetings', 'kuwa', 'able', 'indicates', '}', 'gotten', 'inc', 'k', 'besides', 'came', 'specifying', "they'll", 'let', 'enough', 'novel', 'hereupon', 'th', "we'd", 'there', "it'll", 'them', 'j', 'sub', 'when', 'whose', 'x', 'specified', 'far', 'g', 'whatever', 'relatively', "you're", 'her', 'two', 'into', '%', 'one', 'almost', 'could', 'second', "he's", 'down', 'value', "that's", 'see', "she's", 'having', 'anyone', "t's", 'yake', "wouldn't", 'currently', 'trying', 'me', 'not', 'ma', "don't", 'nor', 'certain', 'shall', 'then', 'despite', 'became', 'myself', 'out', 'ng', 'via', 'cant', 'thereby', "c's", 'mara', 'following', 'maybe', 'everyone', 'self', "they're", 'moja', 'wants', 'alikuwa', 'i', "they've", 'anyhow', 'every', 'do', 'wish', "here's", 'whereas', 'whether', "who's", ' ...

# %%
#Tokenization
new_corpus = []
for sent in corpus: 
    token = [token.lower() for token in word_tokenize(sent) if token not in stopwords_all]
    new_corpus.append(token)
    # list(map(str.lower, word_tokenize(sent)))  
new_corpus
# Out:
# [['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['breastfeeding',
#   'baby',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'cleans',
#   'stomach',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['make',
#   '4',
#   'times',
#   'antenatal',
#   'care',
#   'we',
#   'check',
#   'blood',
#   'strong',
#   'check',
#   'problems',
#   'prepare',
#   'birth',
#   'plan',
#   'the',
#   '4th',
#   'visit',
#   'includes',
#   'checking',
#   'baby',
#   'good',
#   'position',
#   'do',
#   'questions',
#   'concerns',
#   'are',
#   'feeling',
#   'baby',
#   'move'],
#  ['it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['have', 'baby', 'please', 'problems', 'where', 'delivering', 'baby'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['you',
#   'starting',
#   'labour',
#   'make',
#   'bring',
#   'cotton',
#   'wool',
#   'clothes',
#   'baby',
#   'medications',
#   'hospital',
#   'do',
#   'questions',
#   'bring'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['breastfeeding',
#   'baby',
#   'immediately',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'protects',
#   'baby',
#   'illness',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['babies',
#   'age',
#   'smiling',
#   'reaching',
#   'things',
#   'try',
#   'putting',
#   'rattle',
#   'toy',
#   'grasp',
#   'is',
#   'baby',
#   'reaching',
#   'things',
#   'do',
#   'concerns'],
#  ['have',
#   'injection',
#   'family',
#   'planning',
#   'it',
#   'effective',
#   'works',
#   'women',
#   'safe',
#   'breastfeeding',
#   'some',
#   'women',
#   'experience',
#   'irregular',
#   'bleeding',
#   'frequent',
#   'frequent',
#   'periods',
#   'if',
#   'regular',
#   'predicatable',
#   'periods',
#   'method'],
#  ['it',
#   'space',
#   'children',
#   'think',
#   'family',
#   'planning',
#   'there',
#   'options',
#   'choice',
#   'please',
#   'talk',
#   'family',
#   'planning',
#   'visit',
#   'can',
#   'advice'],
#  ['until',
#   'baby',
#   'reaches',
#   '3',
#   'months',
#   'bring',
#   'baby',
#   'hospital',
#   'fever',
#   'appretite',
#   'fatigued',
#   'try',
#   'give',
#   'baby',
#   'medication',
#   'talking',
#   'have',
#   'noticed',
#   'week'],
#  ['when',
#   'start',
#   'family',
#   'planning',
#   'method',
#   'side',
#   'effects',
#   'body',
#   'time',
#   'adjust',
#   'usually',
#   'subside',
#   'weeks',
#   'before',
#   'stop',
#   'change',
#   'methods',
#   'talk',
#   'nurses',
#   'have',
#   'chosen',
#   'method',
#   'are',
#   'side',
#   'effects'],
#  ['crying',
#   'distressing',
#   'parents',
#   'if',
#   'baby',
#   'cries',
#   'long',
#   'time',
#   'late',
#   'afternoon',
#   'evening',
#   'colic',
#   'try',
#   'lying',
#   'baby',
#   'lap',
#   'tummy',
#   'rub',
#   'back',
#   'rocking',
#   'face',
#   'arm',
#   'let',
#   'exeprience',
#   'advice'],
#  ['irregular',
#   'bleeding',
#   'common',
#   'breastfeeding',
#   'family',
#   'planning',
#   'methods',
#   'it',
#   'wrong',
#   'do',
#   'concerns',
#   'bleeding',
#   'family',
#   'planning'],
#  ['babies',
#   'poo',
#   'day',
#   'if',
#   'baby',
#   'times',
#   'week',
#   'fussy',
#   'are',
#   'concerns'],
#  ['sometimes',
#   'mothers',
#   'feel',
#   'sad',
#   'anxious',
#   'worried',
#   'time',
#   'this',
#   'women',
#   'crying',
#   'difficulty',
#   'sleeping',
#   'are',
#   'problems'],
#  ['family',
#   'planning',
#   'methods',
#   'work',
#   'differently',
#   'women',
#   'what',
#   'methods',
#   'past',
#   'did',
#   'methods',
#   'do',
#   'plan'],
#  ['your',
#   'baby',
#   'hold',
#   'head',
#   'spend',
#   'minutes',
#   'day',
#   'playing',
#   'lay',
#   'stomach',
#   'this',
#   'develop',
#   'muscles',
#   'start',
#   'crawling',
#   'work',
#   '15',
#   'minutes',
#   'day',
#   'do',
#   'questions',
#   'baby',
#   "'s",
#   'development'],
#  ['if',
#   'baby',
#   'frequent',
#   'spitting',
#   'vomiting',
#   'makes',
#   'gagging',
#   'noises',
#   'uncomfortable',
#   'reflux',
#   'smaller',
#   'frequent',
#   'feedings',
#   'keeping',
#   'baby',
#   'upright',
#   'feeding',
#   'is',
#   'baby',
#   'isseus',
#   'feeding'],
#  ['this',
#   'week',
#   'messages',
#   'stopping',
#   'please',
#   'final',
#   'visit',
#   'baby',
#   '14',
#   'weeks',
#   'let',
#   'difficulty',
#   'coming',
#   'we',
#   'experience',
#   'service',
#   'helpful',
#   'we',
#   'forward'],
#  ['thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'the',
#   'messages',
#   'stop',
#   'questions',
#   'has',
#   'helpful',
#   'baby'],
#  ['thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'this',
#   'message',
#   'please',
#   'program',
#   'visit',
#   'when',
#   'visit',
#   'please',
#   'schedule'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeidng',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'please',
#   'problems',
#   'where',
#   'delivering',
#   'baby'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'you',
#   'starting',
#   'labour',
#   'make',
#   'bring',
#   'cotton',
#   'wool',
#   'clothes',
#   'baby',
#   'medications',
#   'hospital',
#   'do',
#   'questions',
#   'bring'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'congratulations',
#   'baby',
#   'we',
#   'happy',
#   'please',
#   'questions',
#   'where',
#   'deliver',
#   'how',
#   'baby',
#   'how'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'breastfeeding',
#   'baby',
#   'immediately',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'protects',
#   'baby',
#   'illness',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'by',
#   'weeks',
#   'typical',
#   'newborn',
#   'cry',
#   '2',
#   'hours',
#   'day',
#   'make',
#   'baby',
#   'hungry',
#   'tired',
#   'soiled',
#   'diaper',
#   'pay',
#   'attention',
#   'soothes',
#   'baby',
#   'singing',
#   'rocking',
#   'swaddling',
#   'sucking',
#   'does',
#   'baby',
#   'cry',
#   '30',
#   'minutes',
#   'time',
#   'are',
#   'problems'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'how',
#   'baby',
#   'your',
#   'baby',
#   '3',
#   'weeks',
#   'have',
#   '2',
#   'week',
#   'check'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'babies',
#   'breath',
#   'fast',
#   'problem',
#   'grunting',
#   'nose',
#   'flares',
#   'wheezing',
#   'you',
#   'notice',
#   'is',
#   'baby',
#   'issues',
#   'breathing',
#   'feeding'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'newborns',
#   'sleep',
#   'lot',
#   'wo',
#   "n't",
#   'stay',
#   'asleep',
#   '2-4',
#   'hours',
#   'time',
#   'you',
#   'times',
#   'night',
#   'change',
#   'feed',
#   'comfort',
#   'baby',
#   'take',
#   'naps',
#   'baby',
#   'interact',
#   'baby',
#   'day',
#   'things',
#   'dark',
#   'quiet',
#   'night',
#   'how',
#   'baby',
#   'sleeping'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'how',
#   'feeling',
#   'it',
#   'normal',
#   'feel',
#   'tired',
#   'pain',
#   'delivery'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'over',
#   'weeks',
#   'send',
#   'messages',
#   'make',
#   'family',
#   'planning',
#   'decisions',
#   'planning',
#   'family',
#   'spacing',
#   'pregnancy',
#   'good',
#   'health',
#   'are',
#   'planning',
#   'pregnancy',
#   'future'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'the',
#   'implant',
#   'family',
#   'planning',
#   'it',
#   'arm',
#   'effective',
#   '3',
#   'years',
#   'the',
#   'implant',
#   'removed',
#   'time',
#   'ask',
#   'implant',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'questions',
#   'implant'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'the',
#   'iucd',
#   'coil',
#   'effective',
#   'family',
#   'planning',
#   'easy',
#   'put',
#   'safe',
#   'years',
#   'iucd',
#   'coil',
#   'removed',
#   'time',
#   'ask',
#   'coil',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'coil'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'your',
#   'baby',
#   'soft',
#   'places',
#   'head',
#   'fontanelles',
#   'skull',
#   'bones',
#   "n't",
#   'fused',
#   'this',
#   'nature',
#   "'s",
#   'allowing',
#   'head',
#   'pass',
#   'birth',
#   'canal',
#   'if',
#   'fontanelle',
#   'sunken',
#   'sign',
#   'dehydration',
#   'they',
#   'bulge',
#   'slightly',
#   'baby',
#   'crying',
#   'return',
#   'normal',
#   'stop',
#   '–',
#   'doctor',
#   'have',
#   'noticed'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'your',
#   'baby',
#   'due',
#   'polio',
#   'dpt',
#   'pneumococcal',
#   'vaccines',
#   'has',
#   'baby',
#   'received',
#   '6',
#   'week',
#   'vaccines'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'babies',
#   'age',
#   'smiling',
#   'reaching',
#   'things',
#   'try',
#   'putting',
#   'rattle',
#   'toy',
#   'grasp',
#   'is',
#   'baby',
#   'reaching',
#   'things',
#   'do',
#   'concerns'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'have',
#   'injection',
#   'family',
#   'planning',
#   'it',
#   'effective',
#   'works',
#   'women',
#   'safe',
#   'breastfeeding',
#   'some',
#   'women',
#   'experience',
#   'irregular',
#   'bleeding',
#   'frequent',
#   'frequent',
#   'periods',
#   'if',
#   'regular',
#   'predicatable',
#   'periods',
#   'method'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'it',
#   'space',
#   'children',
#   'think',
#   'family',
#   'planning',
#   'there',
#   'options',
#   'choice',
#   'please',
#   'talk',
#   'family',
#   'planning',
#   'visit',
#   'can',
#   'advice'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'until',
#   'baby',
#   'reaches',
#   '3',
#   'months',
#   'bring',
#   'baby',
#   'hospital',
#   'fever',
#   'appretite',
#   'fatigued',
#   'try',
#   'give',
#   'baby',
#   'medication',
#   'talking',
#   'have',
#   'noticed',
#   'week'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'when',
#   'start',
#   'family',
#   'planning',
#   'method',
#   'side',
#   'effects',
#   'body',
#   'time',
#   'adjust',
#   'usually',
#   'subside',
#   'weeks',
#   'before',
#   'stop',
#   'change',
#   'methods',
#   'talk',
#   'nurses',
#   'have',
#   'chosen',
#   'method',
#   'are',
#   'side',
#   'effects'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'crying',
#   'distressing',
#   'parents',
#   'if',
#   'baby',
#   'cries',
#   'long',
#   'time',
#   'late',
#   'afternoon',
#   'evening',
#   'colic',
#   'try',
#   'lying',
#   'baby',
#   'lap',
#   'tummy',
#   'rub',
#   'back',
#   'rocking',
#   'face',
#   'arm',
#   'let',
#   'exeprience',
#   'advice'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'irregular',
#   'bleeding',
#   'common',
#   'breastfeeding',
#   'family',
#   'planning',
#   'methods',
#   'it',
#   'wrong',
#   'do',
#   'concerns',
#   'bleeding',
#   'family',
#   'planning'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'babies',
#   'poo',
#   'day',
#   'if',
#   'baby',
#   'times',
#   'week',
#   'fussy',
#   'are',
#   'concerns'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'sometimes',
#   'mothers',
#   'feel',
#   'sad',
#   'anxious',
#   'worried',
#   'time',
#   'this',
#   'women',
#   'crying',
#   'difficulty',
#   'sleeping',
#   'are',
#   'problems'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'family',
#   'planning',
#   'methods',
#   'work',
#   'differently',
#   'women',
#   'what',
#   'methods',
#   'past',
#   'did',
#   'methods',
#   'do',
#   'plan'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'your',
#   'baby',
#   'hold',
#   'head',
#   'spend',
#   'minutes',
#   'day',
#   'playing',
#   'lay',
#   'stomach',
#   'this',
#   'develop',
#   'muscles',
#   'start',
#   'crawling',
#   'work',
#   '15',
#   'minutes',
#   'day',
#   'do',
#   'questions',
#   'baby',
#   "'s",
#   'development'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'if',
#   'baby',
#   'frequent',
#   'spitting',
#   'vomiting',
#   'makes',
#   'gagging',
#   'noises',
#   'uncomfortable',
#   'reflux',
#   'smaller',
#   'frequent',
#   'feedings',
#   'keeping',
#   'baby',
#   'upright',
#   'feeding',
#   'is',
#   'baby',
#   'isseus',
#   'feeding'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'this',
#   'week',
#   'messages',
#   'stopping',
#   'please',
#   'final',
#   'visit',
#   'baby',
#   '14',
#   'weeks',
#   'let',
#   'diffculty',
#   'coming',
#   'we',
#   'experience',
#   'service',
#   'helpful',
#   'we',
#   'forward'],
#  ['asha',
#   'brenda',
#   'mathare',
#   'thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'the',
#   'messages',
#   'stop',
#   'service',
#   'questions',
#   'september',
#   'has',
#   'helpful',
#   'baby',
#   'please',
#   'visit'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['breastfeeding',
#   'baby',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'cleans',
#   'stomach',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['make',
#   '4',
#   'times',
#   'antenatal',
#   'care',
#   'we',
#   'check',
#   'blood',
#   'strong',
#   'check',
#   'problems',
#   'prepare',
#   'birth',
#   'plan',
#   'the',
#   '4th',
#   'visit',
#   'includes',
#   'checking',
#   'baby',
#   'good',
#   'position',
#   'do',
#   'questions',
#   'concerns',
#   'are',
#   'feeling',
#   'baby',
#   'move'],
#  ['it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['have', 'baby', 'please', 'problems', 'where', 'delivering', 'baby'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['you',
#   'starting',
#   'labour',
#   'make',
#   'bring',
#   'cotton',
#   'wool',
#   'clothes',
#   'baby',
#   'medications',
#   'hospital',
#   'do',
#   'questions',
#   'bring'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['breastfeeding',
#   'baby',
#   'immediately',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'protects',
#   'baby',
#   'illness',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['by',
#   'weeks',
#   'typical',
#   'newborn',
#   'cry',
#   '2',
#   'hours',
#   'day',
#   'make',
#   'baby',
#   'hungry',
#   'tired',
#   'soiled',
#   'diaper',
#   'pay',
#   'attention',
#   'soothes',
#   'baby',
#   'singing',
#   'rocking',
#   'swaddling',
#   'sucking',
#   'does',
#   'baby',
#   'cry',
#   '30',
#   'minutes',
#   'time',
#   'are',
#   'problems'],
#  ['how', 'baby', 'your', 'baby', '3', 'weeks', 'have', '2', 'week', 'check'],
#  ['babies',
#   'breath',
#   'fast',
#   'problem',
#   'grunting',
#   'nose',
#   'flares',
#   'wheezing',
#   'you',
#   'notice',
#   'is',
#   'baby',
#   'issues',
#   'breathing',
#   'feeding'],
#  ['newborns',
#   'sleep',
#   'lot',
#   'wo',
#   "n't",
#   'stay',
#   'asleep',
#   '2-4',
#   'hours',
#   'time',
#   'you',
#   'times',
#   'night',
#   'change',
#   'feed',
#   'comfort',
#   'baby',
#   'take',
#   'naps',
#   'baby',
#   'interact',
#   'baby',
#   'day',
#   'things',
#   'dark',
#   'quiet',
#   'night',
#   'how',
#   'baby',
#   'sleeping'],
#  ['how', 'feeling', 'it', 'normal', 'feel', 'tired', 'pain', 'delivery'],
#  ['over',
#   'weeks',
#   'send',
#   'messages',
#   'make',
#   'family',
#   'planning',
#   'decisions',
#   'planning',
#   'family',
#   'spacing',
#   'pregnancy',
#   'good',
#   'health',
#   'are',
#   'planning',
#   'pregnancy',
#   'future'],
#  ['the',
#   'implant',
#   'family',
#   'planning',
#   'it',
#   'arm',
#   'effective',
#   '3',
#   'years',
#   'the',
#   'implant',
#   'removed',
#   'time',
#   'ask',
#   'implant',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'questions',
#   'implant'],
#  ['the',
#   'iucd',
#   'coil',
#   'effective',
#   'family',
#   'planning',
#   'easy',
#   'put',
#   'safe',
#   'years',
#   'iucd',
#   'coil',
#   'removed',
#   'time',
#   'ask',
#   'coil',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'coil'],
#  ['your',
#   'baby',
#   'soft',
#   'places',
#   'head',
#   'fontanelles',
#   'skull',
#   'bones',
#   "n't",
#   'fused',
#   'this',
#   'nature',
#   "'s",
#   'allowing',
#   'head',
#   'pass',
#   'birth',
#   'canal',
#   'if',
#   'fontanelle',
#   'sunken',
#   'sign',
#   'dehydration',
#   'they',
#   'bulge',
#   'slightly',
#   'baby',
#   'crying',
#   'return',
#   'normal',
#   'stop',
#   '–',
#   'doctor',
#   'have',
#   'noticed'],
#  ['your',
#   'baby',
#   'due',
#   'polio',
#   'dpt',
#   'pneumococcal',
#   'vaccines',
#   'has',
#   'baby',
#   'received',
#   '6',
#   'week',
#   'vaccines'],
#  ['babies',
#   'age',
#   'smiling',
#   'reaching',
#   'things',
#   'try',
#   'putting',
#   'rattle',
#   'toy',
#   'grasp',
#   'is',
#   'baby',
#   'reaching',
#   'things',
#   'do',
#   'concerns'],
#  ['have',
#   'injection',
#   'family',
#   'planning',
#   'it',
#   'effective',
#   'works',
#   'women',
#   'safe',
#   'breastfeeding',
#   'some',
#   'women',
#   'experience',
#   'irregular',
#   'bleeding',
#   'frequent',
#   'frequent',
#   'periods',
#   'if',
#   'regular',
#   'predicatable',
#   'periods',
#   'method'],
#  ['it',
#   'space',
#   'children',
#   'think',
#   'family',
#   'planning',
#   'there',
#   'options',
#   'choice',
#   'please',
#   'talk',
#   'family',
#   'planning',
#   'visit',
#   'can',
#   'advice'],
#  ['until',
#   'baby',
#   'reaches',
#   '3',
#   'months',
#   'bring',
#   'baby',
#   'hospital',
#   'fever',
#   'appretite',
#   'fatigued',
#   'try',
#   'give',
#   'baby',
#   'medication',
#   'talking',
#   'have',
#   'noticed',
#   'week'],
#  ['when',
#   'start',
#   'family',
#   'planning',
#   'method',
#   'side',
#   'effects',
#   'body',
#   'time',
#   'adjust',
#   'usually',
#   'subside',
#   'weeks',
#   'before',
#   'stop',
#   'change',
#   'methods',
#   'talk',
#   'nurses',
#   'have',
#   'chosen',
#   'method',
#   'are',
#   'side',
#   'effects'],
#  ['crying',
#   'distressing',
#   'parents',
#   'if',
#   'baby',
#   'cries',
#   'long',
#   'time',
#   'late',
#   'afternoon',
#   'evening',
#   'colic',
#   'try',
#   'lying',
#   'baby',
#   'lap',
#   'tummy',
#   'rub',
#   'back',
#   'rocking',
#   'face',
#   'arm',
#   'let',
#   'exeprience',
#   'advice'],
#  ['irregular',
#   'bleeding',
#   'common',
#   'breastfeeding',
#   'family',
#   'planning',
#   'methods',
#   'it',
#   'wrong',
#   'do',
#   'concerns',
#   'bleeding',
#   'family',
#   'planning'],
#  ['babies',
#   'poo',
#   'day',
#   'if',
#   'baby',
#   'times',
#   'week',
#   'fussy',
#   'are',
#   'concerns'],
#  ['sometimes',
#   'mothers',
#   'feel',
#   'sad',
#   'anxious',
#   'worried',
#   'time',
#   'this',
#   'women',
#   'crying',
#   'difficulty',
#   'sleeping',
#   'are',
#   'problems'],
#  ['family',
#   'planning',
#   'methods',
#   'work',
#   'differently',
#   'women',
#   'what',
#   'methods',
#   'past',
#   'did',
#   'methods',
#   'do',
#   'plan'],
#  ['your',
#   'baby',
#   'hold',
#   'head',
#   'spend',
#   'minutes',
#   'day',
#   'playing',
#   'lay',
#   'stomach',
#   'this',
#   'develop',
#   'muscles',
#   'start',
#   'crawling',
#   'work',
#   '15',
#   'minutes',
#   'day',
#   'do',
#   'questions',
#   'baby',
#   "'s",
#   'development'],
#  ['if',
#   'baby',
#   'frequent',
#   'spitting',
#   'vomiting',
#   'makes',
#   'gagging',
#   'noises',
#   'uncomfortable',
#   'reflux',
#   'smaller',
#   'frequent',
#   'feedings',
#   'keeping',
#   'baby',
#   'upright',
#   'feeding',
#   'is',
#   'baby',
#   'isseus',
#   'feeding'],
#  ['this',
#   'week',
#   'messages',
#   'stopping',
#   'please',
#   'final',
#   'visit',
#   'baby',
#   '14',
#   'weeks',
#   'let',
#   'difficulty',
#   'coming',
#   'we',
#   'experience',
#   'service',
#   'helpful',
#   'we',
#   'forward'],
#  ['thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'the',
#   'messages',
#   'stop',
#   'questions',
#   'has',
#   'helpful',
#   'baby'],
#  ['thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'this',
#   'message',
#   'please',
#   'program',
#   'visit',
#   'when',
#   'visit',
#   'please',
#   'schedule'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'breastfeeding',
#   'baby',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'cleans',
#   'stomach',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'make',
#   '4',
#   'times',
#   'antenatal',
#   'care',
#   'we',
#   'check',
#   'blood',
#   'strong',
#   'check',
#   'problems',
#   'prepare',
#   'birth',
#   'plan',
#   'the',
#   '4th',
#   'visit',
#   'includes',
#   'checking',
#   'baby',
#   'good',
#   'position',
#   'do',
#   'questions',
#   'concerns',
#   'are',
#   'feeling',
#   'baby',
#   'move'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'please',
#   'problems',
#   'where',
#   'delivering',
#   'baby'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'you',
#   'starting',
#   'labour',
#   'make',
#   'bring',
#   'cotton',
#   'wool',
#   'clothes',
#   'baby',
#   'medications',
#   'hospital',
#   'do',
#   'questions',
#   'bring'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'you',
#   'facility',
#   'heavy',
#   'bleeding',
#   'severe',
#   'pain',
#   'fevers',
#   'fits',
#   'bad',
#   'headache',
#   'have',
#   'problems'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'you',
#   'prevent',
#   'infections',
#   'washing',
#   'hands',
#   'keeping',
#   'cord',
#   'clean',
#   'are',
#   'challenges',
#   'baby'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'how',
#   'feeling',
#   'breast',
#   'milk',
#   'food',
#   'baby',
#   'food',
#   'fluid',
#   'baby',
#   'it',
#   'protects',
#   'infant',
#   'infections',
#   'a',
#   'baby',
#   'breastfed',
#   '8',
#   'times',
#   'day',
#   'month',
#   'how',
#   'breastfeeding',
#   'baby'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'breath',
#   'faster',
#   'older',
#   'children',
#   'fast',
#   'sign',
#   'infection',
#   'the',
#   'baby',
#   'breath',
#   '60',
#   'times',
#   'minute',
#   'if',
#   'worried',
#   'baby',
#   "'s",
#   'breathing',
#   'count',
#   'number',
#   'breaths',
#   'minute',
#   'have',
#   'noticed',
#   'problems',
#   'baby',
#   "'s",
#   'breathing'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'sleep',
#   'time',
#   'when',
#   'baby',
#   'awake',
#   'move',
#   'arms',
#   'legs',
#   'turn',
#   'head',
#   'if',
#   'baby',
#   "n't",
#   'move',
#   'awake',
#   'stimulating',
#   'baby',
#   'tapping',
#   'foot',
#   'if',
#   'baby',
#   'moves',
#   'stops',
#   'danger',
#   'sign',
#   'baby',
#   'or',
#   'baby',
#   "n't",
#   'move',
#   'danger',
#   'sign',
#   'is',
#   'baby',
#   'moving',
#   'awake'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'how',
#   'baby',
#   'have',
#   'noted',
#   'convulsions',
#   'fits',
#   'baby'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'the',
#   'umbilical',
#   'cord',
#   'stump',
#   'dry',
#   'fall',
#   '1-3',
#   'weeks',
#   'there',
#   'bleeding',
#   'if',
#   'area',
#   'painful',
#   'red',
#   'smelly',
#   'discharge',
#   'is',
#   'area',
#   'healing'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'enjoy',
#   'baby',
#   'talk',
#   'learn',
#   'signals',
#   'sleepy',
#   'hungry',
#   'some',
#   'babies',
#   'hungry',
#   'cry',
#   'suck',
#   'hands',
#   'smack',
#   'lips',
#   'turn',
#   'head',
#   'breast',
#   'bottle',
#   'have',
#   'noticed',
#   'pattern',
#   'baby'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'by',
#   'weeks',
#   'typical',
#   'newborn',
#   'cry',
#   '2',
#   'hours',
#   'day',
#   'make',
#   'baby',
#   'hungry',
#   'tired',
#   'soiled',
#   'diaper',
#   'pay',
#   'attention',
#   'soothes',
#   'baby',
#   'singing',
#   'rocking',
#   'swaddling',
#   'sucking',
#   'does',
#   'baby',
#   'cry',
#   '30',
#   'minutes',
#   'time',
#   'are',
#   'problems'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'how',
#   'baby',
#   'your',
#   'baby',
#   '3',
#   'weeks',
#   'have',
#   '2',
#   'week',
#   'check'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'breath',
#   'fast',
#   'problem',
#   'grunting',
#   'nose',
#   'flares',
#   'wheezing',
#   'you',
#   'notice',
#   'is',
#   'baby',
#   'issues',
#   'breathing',
#   'feeding'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'newborns',
#   'sleep',
#   'lot',
#   'wo',
#   "n't",
#   'stay',
#   'asleep',
#   '2-4',
#   'hours',
#   'time',
#   'you',
#   'times',
#   'night',
#   'change',
#   'feed',
#   'comfort',
#   'baby',
#   'take',
#   'naps',
#   'baby',
#   'interact',
#   'baby',
#   'day',
#   'things',
#   'dark',
#   'quiet',
#   'night',
#   'how',
#   'baby',
#   'sleeping'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'how',
#   'feeling',
#   'it',
#   'normal',
#   'feel',
#   'tired',
#   'pain',
#   'delivery'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'over',
#   'weeks',
#   'send',
#   'messages',
#   'make',
#   'family',
#   'planning',
#   'decisions',
#   'planning',
#   'family',
#   'spacing',
#   'pregnancy',
#   'good',
#   'health',
#   'are',
#   'planning',
#   'pregnancy',
#   'future'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'the',
#   'implant',
#   'family',
#   'planning',
#   'it',
#   'arm',
#   'effective',
#   '3',
#   'years',
#   'the',
#   'implant',
#   'removed',
#   'time',
#   'ask',
#   'implant',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'questions',
#   'implant'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'the',
#   'iucd',
#   'coil',
#   'effective',
#   'family',
#   'planning',
#   'easy',
#   'put',
#   'safe',
#   'years',
#   'iucd',
#   'coil',
#   'removed',
#   'time',
#   'ask',
#   'coil',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'coil'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'your',
#   'baby',
#   'soft',
#   'places',
#   'head',
#   'fontanelles',
#   'skull',
#   'bones',
#   "n't",
#   'fused',
#   'this',
#   'nature',
#   "'s",
#   'allowing',
#   'head',
#   'pass',
#   'birth',
#   'canal',
#   'if',
#   'fontanelle',
#   'sunken',
#   'sign',
#   'dehydration',
#   'they',
#   'bulge',
#   'slightly',
#   'baby',
#   'crying',
#   'return',
#   'normal',
#   'stop',
#   '–',
#   'doctor',
#   'have',
#   'noticed'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'your',
#   'baby',
#   'due',
#   'polio',
#   'dpt',
#   'pneumococcal',
#   'vaccines',
#   'has',
#   'baby',
#   'received',
#   '6',
#   'week',
#   'vaccines'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'age',
#   'smiling',
#   'reaching',
#   'things',
#   'try',
#   'putting',
#   'rattle',
#   'toy',
#   'grasp',
#   'is',
#   'baby',
#   'reaching',
#   'things',
#   'do',
#   'concerns'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'injection',
#   'family',
#   'planning',
#   'it',
#   'effective',
#   'works',
#   'women',
#   'safe',
#   'breastfeeding',
#   'some',
#   'women',
#   'experience',
#   'irregular',
#   'bleeding',
#   'frequent',
#   'frequent',
#   'periods',
#   'if',
#   'regular',
#   'predicatable',
#   'periods',
#   'method'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'it',
#   'space',
#   'children',
#   'think',
#   'family',
#   'planning',
#   'there',
#   'options',
#   'choice',
#   'please',
#   'talk',
#   'family',
#   'planning',
#   'visit',
#   'can',
#   'advice'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'until',
#   'baby',
#   'reaches',
#   '3',
#   'months',
#   'bring',
#   'baby',
#   'hospital',
#   'fever',
#   'appretite',
#   'fatigued',
#   'try',
#   'give',
#   'baby',
#   'medication',
#   'talking',
#   'have',
#   'noticed',
#   'week'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'when',
#   'start',
#   'family',
#   'planning',
#   'method',
#   'side',
#   'effects',
#   'body',
#   'time',
#   'adjust',
#   'usually',
#   'subside',
#   'weeks',
#   'before',
#   'stop',
#   'change',
#   'methods',
#   'talk',
#   'nurses',
#   'have',
#   'chosen',
#   'method',
#   'are',
#   'side',
#   'effects'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'crying',
#   'distressing',
#   'parents',
#   'if',
#   'baby',
#   'cries',
#   'long',
#   'time',
#   'late',
#   'afternoon',
#   'evening',
#   'colic',
#   'try',
#   'lying',
#   'baby',
#   'lap',
#   'tummy',
#   'rub',
#   'back',
#   'rocking',
#   'face',
#   'arm',
#   'let',
#   'exeprience',
#   'advice'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'irregular',
#   'bleeding',
#   'common',
#   'breastfeeding',
#   'family',
#   'planning',
#   'methods',
#   'it',
#   'wrong',
#   'do',
#   'concerns',
#   'bleeding',
#   'family',
#   'planning'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'poo',
#   'day',
#   'if',
#   'baby',
#   'times',
#   'week',
#   'fussy',
#   'are',
#   'concerns'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'sometimes',
#   'mothers',
#   'feel',
#   'sad',
#   'anxious',
#   'worried',
#   'time',
#   'this',
#   'women',
#   'crying',
#   'difficulty',
#   'sleeping',
#   'are',
#   'problems'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'family',
#   'planning',
#   'methods',
#   'work',
#   'differently',
#   'women',
#   'what',
#   'methods',
#   'past',
#   'did',
#   'methods',
#   'do',
#   'plan'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'your',
#   'baby',
#   'hold',
#   'head',
#   'spend',
#   'minutes',
#   'day',
#   'playing',
#   'lay',
#   'stomach',
#   'this',
#   'develop',
#   'muscles',
#   'start',
#   'crawling',
#   'work',
#   '15',
#   'minutes',
#   'day',
#   'do',
#   'questions',
#   'baby',
#   "'s",
#   'development'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'if',
#   'baby',
#   'frequent',
#   'spitting',
#   'vomiting',
#   'makes',
#   'gagging',
#   'noises',
#   'uncomfortable',
#   'reflux',
#   'smaller',
#   'frequent',
#   'feedings',
#   'keeping',
#   'baby',
#   'upright',
#   'feeding',
#   'is',
#   'baby',
#   'isseus',
#   'feeding'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'this',
#   'week',
#   'messages',
#   'stopping',
#   'please',
#   'final',
#   'visit',
#   'baby',
#   '14',
#   'weeks',
#   'let',
#   'diffculty',
#   'coming',
#   'we',
#   'experience',
#   'service',
#   'helpful',
#   'we',
#   'forward'],
#  ['min',
#   'cathy',
#   'mercy',
#   'rachuonyo',
#   'thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'the',
#   'messages',
#   'stop',
#   'service',
#   'questions',
#   'september',
#   'has',
#   'helpful',
#   'baby',
#   'please',
#   'visit'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'make',
#   '4',
#   'times',
#   'antenatal',
#   'care',
#   'we',
#   'check',
#   'blood',
#   'strong',
#   'check',
#   'problems',
#   'prepare',
#   'birth',
#   'plan',
#   'the',
#   '4th',
#   'visit',
#   'includes',
#   'checking',
#   'baby',
#   'good',
#   'position',
#   'do',
#   'questions',
#   'concerns',
#   'are',
#   'feeling',
#   'baby',
#   'move'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'breastfeeding',
#   'baby',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'cleans',
#   'stomach',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'make',
#   '4',
#   'times',
#   'antenatal',
#   'care',
#   'we',
#   'check',
#   'blood',
#   'strong',
#   'check',
#   'problems',
#   'prepare',
#   'birth',
#   'plan',
#   'the',
#   '4th',
#   'visit',
#   'includes',
#   'checking',
#   'baby',
#   'good',
#   'position',
#   'do',
#   'questions',
#   'concerns',
#   'are',
#   'feeling',
#   'baby',
#   'move'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'please',
#   'problems',
#   'where',
#   'delivering',
#   'baby'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'newborns',
#   'warm',
#   'dry',
#   'baby',
#   'birth',
#   'baby',
#   'skin-to-skin',
#   'please',
#   'avoid',
#   'baths',
#   'days',
#   'when',
#   'baby',
#   'sick',
#   'hot',
#   'cold',
#   'does',
#   'baby',
#   'hot',
#   'cold',
#   'do',
#   'thermometer'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'look',
#   'babies',
#   'hands',
#   'feet',
#   'check',
#   'yellow',
#   'if',
#   'worried',
#   'baby',
#   "'s",
#   'color',
#   'bring',
#   'baby',
#   'facility',
#   'have',
#   'noticed',
#   'signs',
#   'jaundice',
#   'are',
#   'baby',
#   "'s",
#   'hands',
#   'feet',
#   'yellow'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'we',
#   'checking',
#   'how',
#   'bleeding',
#   'do',
#   'pain',
#   'lower',
#   'abdomen',
#   'any',
#   'fevers',
#   'please',
#   'feel',
#   'unwell'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'babies',
#   'sleep',
#   'time',
#   'when',
#   'baby',
#   'awake',
#   'move',
#   'arms',
#   'legs',
#   'turn',
#   'head',
#   'if',
#   'baby',
#   "n't",
#   'move',
#   'awake',
#   'stimulating',
#   'baby',
#   'tapping',
#   'foot',
#   'if',
#   'baby',
#   'moves',
#   'stops',
#   'danger',
#   'sign',
#   'or',
#   'baby',
#   "n't",
#   'move',
#   'danger',
#   'sign',
#   'baby',
#   'is',
#   'baby',
#   'moving',
#   'awake'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'how',
#   'breastfeeding',
#   'baby',
#   'do',
#   'baby',
#   "'s",
#   'weight',
#   'birth'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'one',
#   'places',
#   'baby',
#   'infection',
#   'skin',
#   'pus',
#   'redness',
#   'signs',
#   'infection',
#   'is',
#   'pus',
#   'coming',
#   'umbilical',
#   'cord',
#   'does',
#   'cord',
#   'bad',
#   'smell',
#   'are',
#   'skin',
#   'rashes'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'you',
#   'baby',
#   'health',
#   'facility',
#   'baby',
#   'stops',
#   'breastfeeding',
#   'abnormal',
#   'movement',
#   'jerking',
#   'stiffening',
#   'fast',
#   'breathing',
#   'active',
#   'does',
#   'baby',
#   'problems',
#   'please',
#   'baby',
#   'problems'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'you',
#   'facility',
#   'heavy',
#   'bleeding',
#   'severe',
#   'pain',
#   'fevers',
#   'fits',
#   'bad',
#   'headache',
#   'have',
#   'problems'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'you',
#   'prevent',
#   'infections',
#   'washing',
#   'hands',
#   'keeping',
#   'cord',
#   'clean',
#   'are',
#   'challenges',
#   'baby'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'how',
#   'feeling',
#   'breast',
#   'milk',
#   'food',
#   'baby',
#   'food',
#   'fluid',
#   'baby',
#   'it',
#   'protects',
#   'infant',
#   'infections',
#   'a',
#   'baby',
#   'breastfed',
#   '8',
#   'times',
#   'day',
#   'month',
#   'how',
#   'breastfeeding',
#   'baby'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'babies',
#   'breath',
#   'faster',
#   'older',
#   'children',
#   'fast',
#   'sign',
#   'infection',
#   'the',
#   'baby',
#   'breath',
#   '60',
#   'times',
#   'minute',
#   'if',
#   'worried',
#   'baby',
#   "'s",
#   'breathing',
#   'count',
#   'number',
#   'breaths',
#   'minute',
#   'have',
#   'noticed',
#   'problems',
#   'baby',
#   "'s",
#   'breathing'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'babies',
#   'sleep',
#   'time',
#   'when',
#   'baby',
#   'awake',
#   'move',
#   'arms',
#   'legs',
#   'turn',
#   'head',
#   'if',
#   'baby',
#   "n't",
#   'move',
#   'awake',
#   'stimulating',
#   'baby',
#   'tapping',
#   'foot',
#   'if',
#   'baby',
#   'moves',
#   'stops',
#   'danger',
#   'sign',
#   'baby',
#   'or',
#   'baby',
#   "n't",
#   'move',
#   'danger',
#   'sign',
#   'is',
#   'baby',
#   'moving',
#   'awake'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'how',
#   'baby',
#   'have',
#   'noted',
#   'convulsions',
#   'fits',
#   'baby'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'the',
#   'umbilical',
#   'cord',
#   'stump',
#   'dry',
#   'fall',
#   '1-3',
#   'weeks',
#   'there',
#   'bleeding',
#   'if',
#   'area',
#   'painful',
#   'red',
#   'smelly',
#   'discharge',
#   'is',
#   'area',
#   'healing'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'enjoy',
#   'baby',
#   'talk',
#   'learn',
#   'signals',
#   'sleepy',
#   'hungry',
#   'some',
#   'babies',
#   'hungry',
#   'cry',
#   'suck',
#   'hands',
#   'smack',
#   'lips',
#   'turn',
#   'head',
#   'breast',
#   'bottle',
#   'have',
#   'noticed',
#   'pattern',
#   'baby'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'by',
#   'weeks',
#   'typical',
#   'newborn',
#   'cry',
#   '2',
#   'hours',
#   'day',
#   'make',
#   'baby',
#   'hungry',
#   'tired',
#   'soiled',
#   'diaper',
#   'pay',
#   'attention',
#   'soothes',
#   'baby',
#   'singing',
#   'rocking',
#   'swaddling',
#   'sucking',
#   'does',
#   'baby',
#   'cry',
#   '30',
#   'minutes',
#   'time',
#   'are',
#   'problems'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'how',
#   'baby',
#   'your',
#   'baby',
#   '3',
#   'weeks',
#   'have',
#   '2',
#   'week',
#   'check'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'babies',
#   'breath',
#   'fast',
#   'problem',
#   'grunting',
#   'nose',
#   'flares',
#   'wheezing',
#   'you',
#   'notice',
#   'is',
#   'baby',
#   'issues',
#   'breathing',
#   'feeding'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'newborns',
#   'sleep',
#   'lot',
#   'wo',
#   "n't",
#   'stay',
#   'asleep',
#   '2-4',
#   'hours',
#   'time',
#   'you',
#   'times',
#   'night',
#   'change',
#   'feed',
#   'comfort',
#   'baby',
#   'take',
#   'naps',
#   'baby',
#   'interact',
#   'baby',
#   'day',
#   'things',
#   'dark',
#   'quiet',
#   'night',
#   'how',
#   'baby',
#   'sleeping'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'how',
#   'feeling',
#   'it',
#   'normal',
#   'feel',
#   'tired',
#   'pain',
#   'delivery'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'over',
#   'weeks',
#   'send',
#   'messages',
#   'make',
#   'family',
#   'planning',
#   'decisions',
#   'planning',
#   'family',
#   'spacing',
#   'pregnancy',
#   'good',
#   'health',
#   'are',
#   'planning',
#   'pregnancy',
#   'future'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'the',
#   'implant',
#   'family',
#   'planning',
#   'it',
#   'arm',
#   'effective',
#   '3',
#   'years',
#   'the',
#   'implant',
#   'removed',
#   'time',
#   'ask',
#   'implant',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'questions',
#   'implant'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'the',
#   'iucd',
#   'coil',
#   'effective',
#   'family',
#   'planning',
#   'easy',
#   'put',
#   'safe',
#   'years',
#   'iucd',
#   'coil',
#   'removed',
#   'time',
#   'ask',
#   'coil',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'coil'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'your',
#   'baby',
#   'soft',
#   'places',
#   'head',
#   'fontanelles',
#   'skull',
#   'bones',
#   "n't",
#   'fused',
#   'this',
#   'nature',
#   "'s",
#   'allowing',
#   'head',
#   'pass',
#   'birth',
#   'canal',
#   'if',
#   'fontanelle',
#   'sunken',
#   'sign',
#   'dehydration',
#   'they',
#   'bulge',
#   'slightly',
#   'baby',
#   'crying',
#   'return',
#   'normal',
#   'stop',
#   '–',
#   'doctor',
#   'have',
#   'noticed'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'your',
#   'baby',
#   'due',
#   'polio',
#   'dpt',
#   'pneumococcal',
#   'vaccines',
#   'has',
#   'baby',
#   'received',
#   '6',
#   'week',
#   'vaccines'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'babies',
#   'age',
#   'smiling',
#   'reaching',
#   'things',
#   'try',
#   'putting',
#   'rattle',
#   'toy',
#   'grasp',
#   'is',
#   'baby',
#   'reaching',
#   'things',
#   'do',
#   'concerns'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'have',
#   'injection',
#   'family',
#   'planning',
#   'it',
#   'effective',
#   'works',
#   'women',
#   'safe',
#   'breastfeeding',
#   'some',
#   'women',
#   'experience',
#   'irregular',
#   'bleeding',
#   'frequent',
#   'frequent',
#   'periods',
#   'if',
#   'regular',
#   'predicatable',
#   'periods',
#   'method'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'it',
#   'space',
#   'children',
#   'think',
#   'family',
#   'planning',
#   'there',
#   'options',
#   'choice',
#   'please',
#   'talk',
#   'family',
#   'planning',
#   'visit',
#   'can',
#   'advice'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'until',
#   'baby',
#   'reaches',
#   '3',
#   'months',
#   'bring',
#   'baby',
#   'hospital',
#   'fever',
#   'appretite',
#   'fatigued',
#   'try',
#   'give',
#   'baby',
#   'medication',
#   'talking',
#   'have',
#   'noticed',
#   'week'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'when',
#   'start',
#   'family',
#   'planning',
#   'method',
#   'side',
#   'effects',
#   'body',
#   'time',
#   'adjust',
#   'usually',
#   'subside',
#   'weeks',
#   'before',
#   'stop',
#   'change',
#   'methods',
#   'talk',
#   'nurses',
#   'have',
#   'chosen',
#   'method',
#   'are',
#   'side',
#   'effects'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'crying',
#   'distressing',
#   'parents',
#   'if',
#   'baby',
#   'cries',
#   'long',
#   'time',
#   'late',
#   'afternoon',
#   'evening',
#   'colic',
#   'try',
#   'lying',
#   'baby',
#   'lap',
#   'tummy',
#   'rub',
#   'back',
#   'rocking',
#   'face',
#   'arm',
#   'let',
#   'exeprience',
#   'advice'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'irregular',
#   'bleeding',
#   'common',
#   'breastfeeding',
#   'family',
#   'planning',
#   'methods',
#   'it',
#   'wrong',
#   'do',
#   'concerns',
#   'bleeding',
#   'family',
#   'planning'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'babies',
#   'poo',
#   'day',
#   'if',
#   'baby',
#   'times',
#   'week',
#   'fussy',
#   'are',
#   'concerns'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'sometimes',
#   'mothers',
#   'feel',
#   'sad',
#   'anxious',
#   'worried',
#   'time',
#   'this',
#   'women',
#   'crying',
#   'difficulty',
#   'sleeping',
#   'are',
#   'problems'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'family',
#   'planning',
#   'methods',
#   'work',
#   'differently',
#   'women',
#   'what',
#   'methods',
#   'past',
#   'did',
#   'methods',
#   'do',
#   'plan'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'your',
#   'baby',
#   'hold',
#   'head',
#   'spend',
#   'minutes',
#   'day',
#   'playing',
#   'lay',
#   'stomach',
#   'this',
#   'develop',
#   'muscles',
#   'start',
#   'crawling',
#   'work',
#   '15',
#   'minutes',
#   'day',
#   'do',
#   'questions',
#   'baby',
#   "'s",
#   'development'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'if',
#   'baby',
#   'frequent',
#   'spitting',
#   'vomiting',
#   'makes',
#   'gagging',
#   'noises',
#   'uncomfortable',
#   'reflux',
#   'smaller',
#   'frequent',
#   'feedings',
#   'keeping',
#   'baby',
#   'upright',
#   'feeding',
#   'is',
#   'baby',
#   'isseus',
#   'feeding'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'this',
#   'week',
#   'messages',
#   'stopping',
#   'please',
#   'final',
#   'visit',
#   'baby',
#   '14',
#   'weeks',
#   'let',
#   'difficulty',
#   'coming',
#   'we',
#   'experience',
#   'service',
#   'helpful',
#   'we',
#   'forward'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'the',
#   'messages',
#   'stop',
#   'questions',
#   'has',
#   'helpful',
#   'baby'],
#  ['mama',
#   'jose',
#   'brenda',
#   'mathare',
#   'thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'this',
#   'message',
#   'please',
#   'program',
#   'visit',
#   'when',
#   'visit',
#   'please',
#   'schedule'],
#  ['welcome',
# ...
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'please',
#   'problems',
#   'where',
#   'delivering',
#   'baby'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'you',
#   'starting',
#   'labour',
#   'make',
#   'bring',
#   'cotton',
#   'wool',
#   'clothes',
#   'baby',
#   'medications',
#   'hospital',
#   'do',
#   'questions',
#   'bring'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'breastfeeding',
#   'baby',
#   'immediately',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'protects',
#   'baby',
#   'illness',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['martha',
#   'brenda',
#   'mathare',
#   'bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['breastfeeding',
#   'baby',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'cleans',
#   'stomach',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['make',
#   '4',
#   'times',
#   'antenatal',
#   'care',
#   'we',
#   'check',
#   'blood',
#   'strong',
#   'check',
#   'problems',
#   'prepare',
#   'birth',
#   'plan',
#   'the',
#   '4th',
#   'visit',
#   'includes',
#   'checking',
#   'baby',
#   'good',
#   'position',
#   'do',
#   'questions',
#   'concerns',
#   'are',
#   'feeling',
#   'baby',
#   'move'],
#  ['it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['have', 'baby', 'please', 'problems', 'where', 'delivering', 'baby'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['you',
#   'starting',
#   'labour',
#   'make',
#   'bring',
#   'cotton',
#   'wool',
#   'clothes',
#   'baby',
#   'medications',
#   'hospital',
#   'do',
#   'questions',
#   'bring'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['breastfeeding',
#   'baby',
#   'immediately',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'protects',
#   'baby',
#   'illness',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['have', 'baby', 'we', 'please', 'deliver', 'assist', 'baby', 'arrives'],
#  ['bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['sharon',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['sharon',
#   'mercy',
#   'rachuonyo',
#   'breastfeeding',
#   'baby',
#   'immediately',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'protects',
#   'baby',
#   'illness',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['sharon',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['sharon',
#   'mercy',
#   'rachuonyo',
#   'bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'please',
#   'problems',
#   'where',
#   'delivering',
#   'baby'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'you',
#   'facility',
#   'heavy',
#   'bleeding',
#   'severe',
#   'pain',
#   'fevers',
#   'fits',
#   'bad',
#   'headache',
#   'have',
#   'problems'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'you',
#   'prevent',
#   'infections',
#   'washing',
#   'hands',
#   'keeping',
#   'cord',
#   'clean',
#   'are',
#   'challenges',
#   'baby'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'how',
#   'feeling',
#   'breast',
#   'milk',
#   'food',
#   'baby',
#   'food',
#   'fluid',
#   'baby',
#   'it',
#   'protects',
#   'infant',
#   'infections',
#   'a',
#   'baby',
#   'breastfed',
#   '8',
#   'times',
#   'day',
#   'month',
#   'how',
#   'breastfeeding',
#   'baby'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'breath',
#   'faster',
#   'older',
#   'children',
#   'fast',
#   'sign',
#   'infection',
#   'the',
#   'baby',
#   'breath',
#   '60',
#   'times',
#   'minute',
#   'if',
#   'worried',
#   'baby',
#   "'s",
#   'breathing',
#   'count',
#   'number',
#   'breaths',
#   'minute',
#   'have',
#   'noticed',
#   'probelms',
#   'baby',
#   "'s",
#   'breathing'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'sleep',
#   'time',
#   'when',
#   'baby',
#   'awake',
#   'move',
#   'arms',
#   'legs',
#   'turn',
#   'head',
#   'if',
#   'baby',
#   "n't",
#   'move',
#   'awake',
#   'stimulating',
#   'baby',
#   'tapping',
#   'foot',
#   'if',
#   'baby',
#   'moves',
#   'stops',
#   'danger',
#   'sign',
#   'baby',
#   'or',
#   'baby',
#   "n't",
#   'move',
#   'danger',
#   'sign',
#   'is',
#   'baby',
#   'moving',
#   'awake'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'how',
#   'baby',
#   'have',
#   'noted',
#   'convulsions',
#   'fits',
#   'baby'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'the',
#   'implant',
#   'family',
#   'planning',
#   'it',
#   'arm',
#   'effective',
#   '3',
#   'years',
#   'the',
#   'implant',
#   'removed',
#   'time',
#   'ask',
#   'implant',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'questions',
#   'implant'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'the',
#   'iucd',
#   'coil',
#   'effective',
#   'family',
#   'planning',
#   'easy',
#   'put',
#   'safe',
#   'years',
#   'iucd',
#   'coil',
#   'removed',
#   'time',
#   'ask',
#   'coil',
#   'family',
#   'planning',
#   'visit',
#   'do',
#   'coil'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'your',
#   'baby',
#   'soft',
#   'places',
#   'head',
#   'fontanelles',
#   'skull',
#   'bones',
#   "n't",
#   'fused',
#   'this',
#   'nature',
#   "'s",
#   'allowing',
#   'head',
#   'pass',
#   'birth',
#   'canal',
#   'if',
#   'fontanelle',
#   'sunken',
#   'sign',
#   'dehydration',
#   'they',
#   'bulge',
#   'slightly',
#   'baby',
#   'crying',
#   'return',
#   'normal',
#   'stop',
#   '–',
#   'doctor',
#   'have',
#   'noticed'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'your',
#   'baby',
#   'due',
#   'polio',
#   'dpt',
#   'pneumococcal',
#   'vaccines',
#   'has',
#   'baby',
#   'received',
#   '6',
#   'week',
#   'vaccines'],
#  ['babies',
#   'age',
#   'smiling',
#   'reaching',
#   'things',
#   'try',
#   'putting',
#   'rattle',
#   'toy',
#   'grasp',
#   'is',
#   'baby',
#   'reaching',
#   'things',
#   'do',
#   'concerns'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'when',
#   'start',
#   'family',
#   'planning',
#   'method',
#   'side',
#   'effects',
#   'body',
#   'time',
#   'adjust',
#   'usually',
#   'subside',
#   'weeks',
#   'before',
#   'stop',
#   'change',
#   'methods',
#   'talk',
#   'nurses',
#   'have',
#   'chosen',
#   'method',
#   'are',
#   'side',
#   'effects'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'crying',
#   'distressing',
#   'parents',
#   'if',
#   'baby',
#   'cries',
#   'long',
#   'time',
#   'late',
#   'afternoon',
#   'evening',
#   'colic',
#   'try',
#   'lying',
#   'baby',
#   'lap',
#   'tummy',
#   'rub',
#   'back',
#   'rocking',
#   'face',
#   'arm',
#   'let',
#   'exeprience',
#   'advice'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'irregular',
#   'bleeding',
#   'common',
#   'breastfeeding',
#   'family',
#   'planning',
#   'methods',
#   'it',
#   'wrong',
#   'do',
#   'concerns',
#   'bleeding',
#   'family',
#   'planning'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'babies',
#   'poo',
#   'day',
#   'if',
#   'baby',
#   'times',
#   'week',
#   'fussy',
#   'are',
#   'concerns'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'sometimes',
#   'mothers',
#   'feel',
#   'sad',
#   'anxious',
#   'worried',
#   'time',
#   'this',
#   'women',
#   'crying',
#   'difficulty',
#   'sleeping',
#   'are',
#   'problems'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'family',
#   'planning',
#   'methods',
#   'work',
#   'differently',
#   'women',
#   'what',
#   'methods',
#   'past',
#   'did',
#   'methods',
#   'do',
#   'plan'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'your',
#   'baby',
#   'hold',
#   'head',
#   'spend',
#   'minutes',
#   'day',
#   'playing',
#   'lay',
#   'stomach',
#   'this',
#   'develop',
#   'muscles',
#   'start',
#   'crawling',
#   'work',
#   '15',
#   'minutes',
#   'day',
#   'do',
#   'questions',
#   'baby',
#   "'s",
#   'development'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'if',
#   'baby',
#   'frequent',
#   'spitting',
#   'vomiting',
#   'makes',
#   'gagging',
#   'noises',
#   'uncomfortable',
#   'reflux',
#   'smaller',
#   'frequent',
#   'feedings',
#   'keeping',
#   'baby',
#   'upright',
#   'feeding',
#   'is',
#   'baby',
#   'isseus',
#   'feeding'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'this',
#   'week',
#   'messages',
#   'stopping',
#   'please',
#   'final',
#   'visit',
#   'baby',
#   '14',
#   'weeks',
#   'let',
#   'diffculty',
#   'coming',
#   'we',
#   'experience',
#   'service',
#   'helpful',
#   'we',
#   'forward'],
#  ['gladys',
#   'mercy',
#   'rachuonyo',
#   'thank',
#   'joining',
#   'mobile',
#   'wach',
#   'neo',
#   'the',
#   'messages',
#   'stop',
#   'service',
#   'questions',
#   'september',
#   'has',
#   'helpful',
#   'baby',
#   'please',
#   'visit'],
#  ['welcome',
#   'mobile',
#   'wach',
#   'neo',
#   'good',
#   'job',
#   'coming',
#   'visit',
#   'you',
#   'receive',
#   'weekly',
#   'sms',
#   'support',
#   'pregnancy',
#   'months',
#   'baby',
#   "'s",
#   'life',
#   'please',
#   'sms',
#   'back',
#   'questions',
#   'concerns'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'bad',
#   'swelling',
#   'hands',
#   'face',
#   'bad',
#   'headache',
#   'signs',
#   'problem',
#   'ask',
#   'family',
#   'have',
#   'swelling',
#   'headaches',
#   'pregnancy',
#   'are',
#   'worse'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'breastfeeding',
#   'baby',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'cleans',
#   'stomach',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'make',
#   '4',
#   'times',
#   'antenatal',
#   'care',
#   'we',
#   'check',
#   'blood',
#   'strong',
#   'check',
#   'problems',
#   'prepare',
#   'birth',
#   'plan',
#   'the',
#   '4th',
#   'visit',
#   'includes',
#   'checking',
#   'baby',
#   'good',
#   'position',
#   'do',
#   'questions',
#   'concerns',
#   'are',
#   'feeling',
#   'baby',
#   'move'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'it',
#   'safest',
#   'women',
#   'deliver',
#   'health',
#   'facility',
#   'health',
#   'workers',
#   'skills',
#   'equipment',
#   'needed',
#   'ensure',
#   'safe',
#   'delivery',
#   'healthy',
#   'baby',
#   'where',
#   'plan',
#   'deliver'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'sometimes',
#   'problems',
#   'arise',
#   'labour',
#   'delivery',
#   'bleeding',
#   'fits',
#   'require',
#   'skilled',
#   'health',
#   'workers',
#   'medications',
#   'equipment',
#   'treat',
#   'without',
#   'treatment',
#   'mother',
#   'baby',
#   'die',
#   'therefore',
#   'safest',
#   'deliver',
#   'facility',
#   'manage',
#   'problems',
#   'how',
#   'arrive',
#   'facility'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'regular',
#   'strong',
#   'stomach',
#   'pains',
#   'sign',
#   'labour',
#   'if',
#   'feel',
#   'strong',
#   'tightening',
#   'regularly',
#   'pains',
#   'leaking',
#   'fluid',
#   'bleeding',
#   'facility',
#   'do',
#   'feel',
#   'contractions',
#   'do',
#   'concerns'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'please',
#   'problems',
#   'where',
#   'delivering',
#   'baby'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'you',
#   'starting',
#   'labour',
#   'make',
#   'bring',
#   'cotton',
#   'wool',
#   'clothes',
#   'baby',
#   'medications',
#   'hospital',
#   'do',
#   'questions',
#   'bring'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'breastfeeding',
#   'baby',
#   'immediately',
#   'birth',
#   'helps',
#   'milk',
#   'the',
#   'yellow',
#   'sticky',
#   'milk',
#   'vitamins',
#   'protects',
#   'baby',
#   'illness',
#   'milk',
#   'water',
#   'baby',
#   'avoid',
#   'liquids',
#   'are',
#   'planning',
#   'breastfeed'],
#  ['nora',
#   'mercy',
#   'rachuonyo',
#   'have',
#   'baby',
#   'we',
#   'please',
#   'deliver',
#   'assist',
#   'baby',
#   'arrives'],
#  ...]

# %%
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(new_corpus)]
# ndf = pd.DataFrame(documents)

# %%
#convert the list to text so that we can create bigrams
newdoc=[] 
sentence=[]
for doc in new_corpus:
    sentence = " ".join(doc)
    newdoc.append(sentence)

# %%
from numpy  import array
new_docs = array(newdoc)
print(new_docs)
# Out:
# ["welcome mobile wach neo good job coming visit you receive weekly sms support pregnancy months baby 's life please sms back questions concerns"
#  'sometimes problems arise labour delivery bleeding fits require skilled health workers medications equipment treat without treatment mother baby die therefore safest deliver facility manage problems how arrive facility'
#  'bad swelling hands face bad headache signs problem ask family have swelling headaches pregnancy are worse'
#  ...
#  'breastfeeding baby immediately birth helps milk the yellow sticky milk vitamins protects baby illness milk water baby avoid liquids are planning breastfeed'
#  'have baby we please deliver assist baby arrives'
#  'bad swelling hands face bad headache signs problem ask family have swelling headaches pregnancy are worse']

# %%
# Creating Bigrams 
bigram_vec = CountVectorizer(ngram_range = (1,2))
X_ngram = bigram_vec.fit_transform(new_docs)
print(bigram_vec.get_feature_names())
# Out:
# ['14', '14 weeks', '15', '15 minutes', '30', '30 minutes', '4th', '4th visit', '60', '60 times', 'abdomen', 'abdomen any', 'abel', 'abel brenda', 'abnormal', 'abnormal movement', 'achieng', 'achieng brenda', 'achieng mercy', 'active', 'active does', 'adjust', 'adjust usually', 'adory', 'adory mercy', 'aduda', 'aduda mercy', 'advice', 'afternoon', 'afternoon evening', 'age', 'age smiling', 'aisha', 'aisha mercy', 'akeyo', 'akeyo mercy', 'akinyi', 'akinyi brenda', 'alice', 'alice brenda', 'aliciah', 'aliciah brenda', 'aliviza', 'aliviza mercy', 'allowing', 'allowing head', 'alphine', 'alphine mercy', 'aluoch', 'aluoch mercy', 'amani', 'amani brenda', 'ambeza', 'ambeza brenda', 'angel', 'angel brenda', 'angela', 'angela brenda', 'angie', 'angie brenda', 'anita', 'anita mercy', 'ann', 'ann brenda', 'antenatal', 'antenatal care', 'anxious', 'anxious worried', 'any', 'any fevers', 'appretite', 'appretite fatigued', 'aquino', 'aquino mercy', 'are', 'are baby', 'are challenges', 'are concerns', 'are feeling', 'are planning', 'are problems', 'are side', 'are skin', 'are worse', 'area', 'area healing', 'area painful', 'arise', 'arise labour', 'arm', 'arm effective', 'arm let', 'arms', 'arms legs', 'arrive', 'arrive facility', 'arrives', 'asha', 'asha brenda', 'asha mercy', 'ashley', 'ashley brenda', 'ask', 'ask coil', 'ask family', 'ask implant', 'asleep', 'asleep hours', 'assist', 'assist baby', 'athieno', 'athieno brenda', 'athur', 'athur brenda', 'attention', 'attention soothes', 'avoid', 'avoid baths', 'avoid liquids', 'awake', 'awake move', 'awake stimulating', 'aziza', 'aziza brenda', 'babies', 'babies age', 'babies breath', 'babies hands', 'babies hungry', 'babies poo', 'babies sleep', 'baby', 'baby 14', 'baby are', 'baby arrives', 'baby avoid', 'baby awake', 'baby birth', 'baby breastfed', 'baby breastfeeding', 'baby breath', 'baby breathing', 'baby color', 'baby cries', 'baby cry', 'baby crying', 'baby day', 'baby development', 'baby die', 'baby do', 'baby due', 'baby facility', 'baby food', 'baby frequent', 'baby good', 'baby hands', 'baby have', 'baby health', 'baby hold', 'baby hospital', 'baby hot', 'baby how', 'baby hungry', 'baby illness', 'baby immediately', 'baby infection', 'baby interact', 'baby is', 'baby isseus', 'baby issues', 'baby it', 'baby lap', 'baby life', 'baby medication', 'baby medications', 'baby move', 'baby moves', 'baby moving', 'baby or', 'baby please', 'baby problems', 'baby reaches', 'baby reaching', 'baby received', 'baby sick', 'baby singing', 'baby skin', 'baby sleeping', 'baby soft', 'baby stops', 'baby take', 'baby talk', 'baby tapping', 'baby times', 'baby upright', 'baby we', 'baby weeks', 'baby weight', 'baby where', 'baby your', 'back', 'back questions', 'back rocking', 'bad', 'bad headache', 'bad smell', 'bad swelling', 'bakita', 'bakita mercy', 'baths', 'baths days', 'batia', 'batia brenda', 'beatrice', 'beatrice brenda', 'beatrice mercy', 'before', 'before stop', 'belinda', 'belinda brenda', 'belly', 'belly mercy', 'ben', 'ben brenda', 'beril', 'beril mercy', 'betty', 'betty brenda', 'birth', 'birth baby', 'birth canal', 'birth helps', 'birth plan', 'bleeding', 'bleeding common', 'bleeding do', 'bleeding facility', 'bleeding family', 'bleeding fits', 'bleeding frequent', 'bleeding if', 'bleeding severe', 'bleeidng', 'bleeidng facility', 'blood', 'blood strong', 'body', 'body time', 'bones', 'bones fused', 'boss', 'boss lady', 'bottle', 'bottle have', 'bravin', 'bravin brenda', 'breast', 'breast bottle', 'breast milk', 'breastfed', 'breastfed times', 'breastfeed', 'breastfeeding', 'breastfeeding abnormal', 'breastfeeding baby', 'breastfeeding family', 'breastfeeding how', 'breastfeeding some', 'breath', 'breath 60', 'breath fast', 'breath faster', 'breathing', 'breathing active', 'breathing count', 'breathing feeding', 'breaths', 'breaths minute', 'brenda', 'brenda mathare', 'brenda mercy', 'bridgit', 'bridgit brenda', 'brilliant', 'brilliant brenda', 'bring', 'bring baby', 'bring cotton' ...

# %% [markdown]
# # 1. Logistic regression using features of the message only

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,  random_state=5555)

# %%
#We now fit the model
logreg = sklearn.linear_model.LogisticRegression(solver='lbfgs', max_iter=600)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=600, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Let's explore the coefficients
print(logreg.coef_)
# Out:
# [[-0.00805088 -0.03466492  1.4110371  -0.72644675  1.83955388 -0.15442742
#   -0.69743689 -0.57201932]]

# %%
pr = logreg.predict_proba(X_test)
predict = logreg.predict(X_test)
plt.hist(pr[:,0])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
#Testing the performance of this model.
acc_ = accuracy_score(y_test, predict)
acc_
# Out:
# 0.6858284660313557

# %%
#Let's also do roc-auc-score
roc_ = roc_auc_score(y_test, pr[:,1])
roc_
# Out:
# 0.7311323215893423

# %%
print(classification_report(y_test, predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.76      0.73      3715
#          1.0       0.65      0.58      0.61      2791
#
#    micro avg       0.69      0.69      0.69      6506
#    macro avg       0.68      0.67      0.67      6506
# weighted avg       0.68      0.69      0.68      6506

# %%
# Let's see the results visually
fpr, tpr, thresholds = roc_curve(y_test, pr[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.4f)' % roc_)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#K-fold cross validation
rkf = RepeatedKFold(n_splits=2, n_repeats=1, random_state=2652124)
accuracy = []
roc = []
count = 0
acc = 0
model = sklearn.linear_model.LogisticRegression(solver='lbfgs')
for train_index, test_index in rkf.split(X):
    #print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    p = model.predict_proba(X_test)
    accuracy.append(accuracy_score(y_test, pred)*100)  #converting the preditions to 100%
    roc.append(roc_auc_score(y_test, p[:,1]))
kfold_acc= statistics.mean(accuracy)
kfold_roc= statistics.mean(roc)
kfold_roc
# Out:
# 0.7376935366145612

# %%
#Get highest predictor and lowest predictor from the model
coeficients = model.coef_
feature_imp_dict = dict(zip(features_list, coeficients[0]))
feature_imp_dict_sorted = list(sorted(feature_imp_dict.items(), key=lambda kv: kv[1]))
lowest_predictor = list(feature_imp_dict_sorted[0:3])
highest_predictor = list(feature_imp_dict_sorted[len(feature_imp_dict_sorted)-3:])
h_pred = []
for var in highest_predictor:
    h_pred.append(var[0])
l_pred = []
for var in lowest_predictor:
    l_pred.append(var[0])
print(feature_imp_dict)
# Out:
# {'edd_wk': -0.005894799230044373, 'study_wk': -0.03088662269848381, 'past_response': 1.3618129991433447, 'native_langauge': -0.18745762175592356, 'delivery_status': 1.9411430508060268, 'swahili': 0.14542969896290822, 'english': 0.17320566596544607, 'luo': -0.3328873207195135}

# %%
# Let's AUC after KFold
fpr, tpr, thresholds = roc_curve(y_test, p[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.4f)' % kfold_roc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#Save results in a dataframe
results = pd.DataFrame({'Model':'LogReg', 
                        'Features': ",".join(features_list),
                        'Acc_score': acc_,
                        'roc_auc_score': roc_,
                        'kfold_cv_acc': kfold_acc,
                        'kfold_cv_roc': kfold_roc,
                        'highest_predictor': ",".join(h_pred),
                        'lowest_predictor': ",".join(l_pred),
                       }, index = ['Model1'] )
results
# Out:
#          Model                                           Features  Acc_score  \
# Model1  LogReg  edd_wk,study_wk,past_response,native_langauge,...   0.685828
#
#         roc_auc_score  kfold_cv_acc  kfold_cv_roc  \
# Model1       0.731132     69.359368      0.737694
#
#                             highest_predictor              lowest_predictor
# Model1  english,past_response,delivery_status  luo,native_langauge,study_wk

# %% [markdown]
# # 2. Gradient Boosting on Features only

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,  random_state=5555)

# %%
GB_model = sklearn.ensemble.GradientBoostingClassifier()
GB_model.fit(X_train, y_train)   #Using the same splits are used in logreg
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
pr = GB_model.predict_proba(X_test)
predict = GB_model.predict(X_test)
plt.hist(pr[:,0])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
gb_acc_ = accuracy_score(y_test, predict)
gb_acc_
# Out:
# 0.70304334460498

# %%
gb_roc_ = roc_auc_score(y_test, pr[:,1])
gb_roc_
# Out:
# 0.7512670750484758

# %%
# Let's see the results visually
fpr, tpr, thresholds = roc_curve(y_test, pr[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.4f)' % gb_roc_)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#K-fold cross validation
rkf = RepeatedKFold(n_splits=10, n_repeats=3, random_state=2652124)
accuracy = []
roc = []
count = 0
acc = 0
GB_model = sklearn.ensemble.GradientBoostingClassifier()
for train_index, test_index in rkf.split(X, y):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    GB_model.fit(X_train, y_train)
    pred = GB_model.predict(X_test)
    p = GB_model.predict_proba(X_test)
    accuracy.append(accuracy_score(y_test, pred)*100)  #converting the preditions to 100%
    roc.append(roc_auc_score(y_test, p[:,1]))
kfold_acc = statistics.mean(accuracy)
kfold_roc = statistics.mean(roc)
kfold_roc
# Out:
# 0.7564254219239349

# %%
 GB_model.feature_importances_
# Out:
# array([0.04983726, 0.19049842, 0.5954565 , 0.01321656, 0.13213092,
#        0.00061079, 0.00433592, 0.01391364])

# %%
#Get highest predictor and lowest predictor from the model
coeficients = GB_model.feature_importances_
feature_imp_ = dict(zip(features_list, coeficients))
feature_imp_sorted = list(sorted(feature_imp_.items(), key=lambda kv: kv[1]))
lowest_predictor = list(feature_imp_sorted[0:3])
highest_predictor = list(feature_imp_sorted[len(feature_imp_sorted)-3:])
h_pred = []
for var in highest_predictor:
    h_pred.append(var[0])
l_pred = []
for var in lowest_predictor:
    l_pred.append(var[0])

# %%
highest_predictor
# Out:
# [('delivery_status', 0.1321309150750999),
#  ('study_wk', 0.19049842333053874),
#  ('past_response', 0.5954565031072353)]

# %%
# Let's see the results visually
fpr, tpr, thresholds = roc_curve(y_test, p[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % kfold_roc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#Save results in a dataframe
results.append(pd.DataFrame({
               'Model':'GB', 
                        'Features': ",".join(features_list),
                        'Acc_score': gb_acc_,
                        'roc_auc_score': gb_roc_,
                        'kfold_cv_acc': kfold_acc,
                        'kfold_cv_roc': kfold_roc,
                        'highest_predictor': ",".join(h_pred),
                        'lowest_predictor': ",".join(l_pred),
                       }, index = ['Model2'])
               )
# Out:
#          Model                                           Features  Acc_score  \
# Model1  LogReg  edd_wk,study_wk,past_response,native_langauge,...   0.685828
# Model2      GB  edd_wk,study_wk,past_response,native_langauge,...   0.703043
#
#         roc_auc_score  kfold_cv_acc  kfold_cv_roc  \
# Model1       0.731132     69.359368      0.737694
# Model2       0.751267     71.310309      0.756425
#
#                              highest_predictor  \
# Model1   english,past_response,delivery_status
# Model2  delivery_status,study_wk,past_response
#
#                        lowest_predictor
# Model1     luo,native_langauge,study_wk
# Model2  swahili,english,native_langauge

# %% [markdown]
# # Predictions using Gensim doc2vec and Logistic regression

# %%
model = Doc2Vec(documents, vector_size=10, window=10, min_count=1, workers=4, max_epochs = 100)

# %%
y = systemMessagesDF.response.astype(float).values
y_series = systemMessagesDF.response.astype(float)

# %%
# %%time
X_x_ = np.array([model.infer_vector([x_i]) for x_i in array(new_docs)])
# pd.DataFrame(X_x_).to_csv("X_x.csv")

# %%
X_all_ = np.hstack((X_x_, systemMessagesDF[features_list].values.astype(np.float32)))
X_all_
# Out:
# array([[-0.03573443,  0.04802387,  0.0245683 , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.03269024, -0.04268377, -0.00605137, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.00688132,  0.01708394,  0.04836001, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.0323377 ,  0.01412122,  0.0420344 , ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.0174702 , -0.0489518 ,  0.029709  , ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.00688132,  0.01708394,  0.04836001, ...,  1.        ,
#          0.        ,  0.        ]], dtype=float32)

# %%
# make a train/test split for out-of-sample validation
train, test = sklearn.model_selection.train_test_split(range(len(y)))

# %%
y[train]
# Out:
# array([0., 1., 0., ..., 1., 1., 0.])

# %%
y[train]
# Out:
# array([0., 1., 0., ..., 1., 1., 0.])

# %%
#We now fit the model
GB_model = sklearn.ensemble.GradientBoostingClassifier() # sklearn.linear_model.LogisticRegression(solver='lbfgs', max_iter=570)
GB_model.fit(X_all_[train], y[train])
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
set(test) & set(train)
# Out:
# set()

# %%
prediction =  GB_model.predict(X_all_[test])  
pr = GB_model.predict_proba(X_all_[test])      
plt.hist(pr[:,1])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
#Let's also do roc-auc-score
roc_ = roc_auc_score(y[test], pr[:,1])
roc_
# Out:
# 0.7558416360134691

# %%
y_series.iloc[test].value_counts(dropna=False)
# Out:
# 0.0    3699
# 1.0    2807
# Name: response, dtype: int64

# %%
prediction.mean()
# Out:
# 0.42084229941592377

# %%
y.mean()
# Out:
# 0.42707812920333577

# %%
acc = accuracy_score(y[test], prediction)
acc
# Out:
# 0.7148785736243467

# %%
# Let's see the results visually
fpr, tpr, thresholds = roc_curve(y[test], pr[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.4f)' % roc_)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %%
#K-fold cross validation
rkf = RepeatedKFold(n_splits=2, n_repeats=1, random_state=2652124)
accuracy = []
roc = []
count = 0
acc = 0
GB_model = sklearn.ensemble.GradientBoostingClassifier()
for train_index, test_index in rkf.split(X_all_, y):
    X_train, X_test = X_all_[train_index], X_all_[test_index]
    y_train, y_test = y[train_index], y[test_index]
    GB_model.fit(X_train, y[train_index])
    pred = GB_model.predict(X_test)
    p = GB_model.predict_proba(X_test)
    accuracy.append(accuracy_score(y_test, pred)*100)  #converting the preditions to 100%
    roc.append(roc_auc_score(y_test, pred))

kfold_acc_ = statistics.mean(accuracy)
kfold_roc_ = statistics.mean(roc)
kfold_roc_
# Out:
# 0.7036528875489492

# %% [markdown]
# # Predictions using BOW and Logistic Regression

# %%
vectorizer = CountVectorizer()
X_bow = vectorizer.fit_transform(new_docs)
print(vectorizer.get_feature_names())
# Out:
# ['14', '15', '30', '4th', '60', 'aache', 'abby', 'abdomen', 'abel', 'abich', 'abigael', 'abnormal', 'aboro', 'aboy', 'acheng', 'achiel', 'achieng', 'achieng07', 'active', 'adek', 'adhiambo', 'adjust', 'ado', 'adory', 'aduda', 'advice', 'afternoon', 'afya', 'age', 'agnes', 'agness', 'ahinya', 'aina', 'aisha', 'ajenya', 'ajili', 'akeyo', 'akicheza', 'akifikia', 'akifikisha', 'akijinyoosha', 'akilia', 'akinyi', 'akiwa', 'ako', 'albert', 'alex', 'alice', 'aliciah', 'aliviza', 'allowing', 'alopozaliwa', 'alphine', 'aluoch', 'amani', 'ambacho', 'ambako', 'ambao', 'ambayo', 'ambeza', 'ambia', 'amealala', 'ameanza', 'amefikisha', 'amelala', 'amepokea', 'amina', 'aminga', 'amora', 'ana', 'anaacha', 'anaenda', 'anaendeleaje', 'anafikia', 'anahitaji', 'anajinyoosha', 'anakuwa', 'analala', 'analia', 'ananyonya', 'anaonekana', 'anapaswa', 'anapozaliwa', 'anasumbua', 'anatoa', 'anaumwa', 'anaweza', 'anayetumia', 'ane', 'ang', 'angalia', 'angel', 'angela', 'angie', 'angwen', 'anita', 'anjeline', 'ann', 'antenatal', 'anxious', 'any', 'aoko', 'apar', 'aphline', 'appretite', 'aquino', 'are', 'area', 'arise', 'ariyo', 'arm', 'arms', 'arrive', 'arrives', 'asante', 'asha', 'ashley', 'asili', 'ask', 'asleep', 'assist', 'atafanya', 'athieno', 'athur', 'atieno', 'atieno07', 'ato', 'attention', 'au', 'auchiel', 'auma', 'aus', 'avoid', 'awake', 'awali', 'awuor', 'aziza', 'baadhi', 'babay', 'babies', 'baby', 'back', 'bad', 'bade', 'badene', 'badi', 'bado', 'bakita', 'bamni', 'ban', 'bang', 'bar', 'baridi', 'bashir', 'baths', 'batia', 'baya', 'be', 'beatrice', 'bedo', 'before', 'belinda', 'belly', 'ben', 'bende', 'bendo', 'benta', 'ber', 'beril', 'beryl', 'betty', 'bila', 'biro', 'bironegi', 'birth', 'bleeding', 'bleeidng', 'bless', 'blessing', 'blood', 'body', 'bones', 'bora', 'boss', 'bottle', 'bravin', 'breast', 'breastfed', 'breastfeed', 'breastfeeding', 'breath', 'breathing', 'breaths', 'brenda', 'brian', 'bridgit', 'brighton', 'brilliant', 'bring', 'bryan', 'bryson', 'bulge', 'buonjo', 'buoyo', 'by', 'cady', 'caleb', 'can', 'canal', 'care', 'caren', 'caro', 'carol', 'caroline', 'carren', 'catherine', 'cathy', 'chache', 'chafu', 'chaguo', 'chak', 'chake', 'chako', 'chakore', 'chakula', 'challenges', 'chandruogegi', 'chandruok', 'changamoto', 'change', 'chango', 'chanjo', 'chao', 'charity', 'charles', 'check', 'checking', 'chemutai', 'chenro', 'chep', 'chiegni', 'chiemo', 'chieng', 'children', 'chiw', 'chochote', 'chogo', 'choice', 'chop', 'chopo', 'chosen', 'chris', 'christine', 'christne', 'chuer', 'chung', 'chunge', 'chungo', 'chungu', 'chuok', 'chupa', 'chwer', 'clanis', 'clean', 'cleans', 'clint', 'clinton', 'clothes', 'coil', 'cold', 'colic', 'colletah', 'collins', 'color', 'comfort', 'coming', 'common', 'concerns', 'congratulations', 'consolata', 'contractions', 'convulsions', 'cord', 'cotton', 'count', 'crawling', 'cries', 'cry', 'crying', 'cynthia', 'dabby', 'daddy', 'dady', 'daher', 'daika', 'daina0', 'daisy', 'dakika', 'daktari', 'dama', 'damaris', 'damian', 'damson', 'damu', 'dan', 'danger', 'dani', 'daniel', 'dark', 'darren', 'daughter', 'dawa', 'day', 'days', 'debra', 'decisions', 'dehydration', 'del', 'deliah', 'deliver', 'delivering', 'delivery', 'dende', 'dendi', 'dennis', 'denno', 'derick', 'derro', 'develop', 'development', 'dhadhu', 'dhaifu', 'dhi', 'dhidi', 'dhodho', 'dhoge', 'dhogi', 'dhoth', 'di', 'diana', 'diaper', 'dibed', 'dichiel', 'dickens', 'did', 'didah', 'didek', 'die', 'diffculty', 'differently', 'difficulty', 'digomb', 'diher', 'dinah', 'dipo', 'discharge', 'distressing', 'divinah', 'do', 'doctor', 'does', 'dolly', 'dongo', 'dorcas', 'dorcus', 'doreen', 'dorine', 'doris', 'doros', 'dorothy', 'dorry', 'dotty', 'dpt', 'dry', 'due', 'duke', 'duoko', 'dwa', 'dwaro', 'dwe', 'dweche', 'easy', 'ebby', 'edend', 'edith', 'edwe', 'edwin', 'ee', 'effective', 'effects', 'ejumbe', 'eklinik', 'elegant', 'elimbeni', 'eliza', 'elizabeth', 'elsy', 'elvis', 'ema', 'emelda', 'emily', 'emma', 'emmah', 'emmanuel', 'en', 'end', 'endalo', ' ...

# %%
sum_words = X_bow.sum(axis=0) 
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)

# %%
words_freq
# Out:
# [('baby', 19218),
#  ('brenda', 17262),
#  ('mathare', 16288),
#  ('mtoto', 14846),
#  ('huyu', 11302),
#  ('mercy', 10142),
#  ('rachuonyo', 9547),
#  ('mama', 9147),
#  ('wako', 7246),
#  ('au', 7186),
#  ('planning', 3904),
#  ('je', 3890),
#  ('yoyote', 3690),
#  ('ikiwa', 3671),
#  ('family', 3603),
#  ('una', 3521),
#  ('have', 3516),
#  ('do', 3204),
#  ('yako', 3140),
#  ('problems', 2991),
#  ('uzazi', 2976),
#  ('are', 2954),
#  ('if', 2891),
#  ('please', 2774),
#  ('hii', 2583),
#  ('sms', 2448),
#  ('wiki', 2435),
#  ('tafadhali', 2391),
#  ('facility', 2323),
#  ('matatizo', 2272),
#  ('how', 2228),
#  ('nyathi', 2223),
#  ('mawuok', 2203),
#  ('en', 2203),
#  ('bende', 2165),
#  ('bleeding', 2161),
#  ('kujifungua', 2098),
#  ('ka', 2096),
#  ('time', 2089),
#  ('deliver', 2084),
#  ('wach', 2024),
#  ('ishara', 2011),
#  ('kichwa', 2001),
#  ('the', 1996),
#  ('damu', 1990),
#  ('visit', 1981),
#  ('kliniki', 1973),
#  ('mae', 1963),
#  ('kupanga', 1918),
#  ('it', 1905),
#  ('ana', 1870),
#  ('implant', 1868),
#  ('concerns', 1867),
#  ('health', 1859),
#  ('kod', 1852),
#  ('afya', 1837),
#  ('questions', 1790),
#  ('mobile', 1778),
#  ('neo', 1778),
#  ('inaweza', 1734),
#  ('huu', 1729),
#  ('haya', 1727),
#  ('we', 1721),
#  ('coil', 1716),
#  ('you', 1680),
#  ('babies', 1649),
#  ('watoto', 1634),
#  ('kituo', 1630),
#  ('tujulishe', 1629),
#  ('milk', 1610),
#  ('gi', 1603),
#  ('breastfeeding', 1595),
#  ('is', 1552),
#  ('kuja', 1542),
#  ('sign', 1541),
#  ('salama', 1537),
#  ('kata', 1533),
#  ('move', 1501),
#  ('nyuol', 1496),
#  ('pregnancy', 1493),
#  ('women', 1482),
#  ('shida', 1473),
#  ('mar', 1471),
#  ('day', 1451),
#  ('ziara', 1447),
#  ('kunyonyesha', 1435),
#  ('kawaida', 1433),
#  ('maziwa', 1429),
#  ('wowote', 1426),
#  ('weeks', 1412),
#  ('nyathini', 1407),
#  ('njia', 1406),
#  ('mondo', 1365),
#  ('birth', 1346),
#  ('head', 1346),
#  ('ambayo', 1334),
#  ('methods', 1312),
#  ('feel', 1297),
#  ('wasiwasi', 1286),
#  ('this', 1259),
#  ('week', 1258),
#  ('mikono', 1256),
#  ('min', 1250),
#  ('tumbo', 1242),
#  ('tatizo', 1227),
#  ('amora', 1207),
#  ('delivery', 1203),
#  ('jaribu', 1202),
#  ('siku', 1199),
#  ('ujauzito', 1195),
#  ('kwanza', 1182),
#  ('wanawake', 1181),
#  ('wakati', 1164),
#  ('macho', 1145),
#  ('vizuri', 1137),
#  ('ni', 1127),
#  ('hakikisha', 1121),
#  ('awake', 1119),
#  ('bad', 1113),
#  ('plan', 1103),
#  ('maswali', 1102),
#  ('uchungu', 1090),
#  ('labour', 1085),
#  ('make', 1074),
#  ('maji', 1052),
#  ('kuna', 1052),
#  ('noticed', 1040),
#  ('mwingine', 1037),
#  ('frequent', 1028),
#  ('times', 1018),
#  ('hands', 999),
#  ('your', 985),
#  ('kendo', 975),
#  ('workers', 971),
#  ('equipment', 971),
#  ('safest', 971),
#  ('moro', 960),
#  ('mwezi', 957),
#  ('kabisa', 955),
#  ('unaweza', 955),
#  ('safe', 949),
#  ('iucd', 940),
#  ('fits', 935),
#  ('lolote', 929),
#  ('kupata', 927),
#  ('when', 927),
#  ('upangaji', 923),
#  ('kuhusu', 887),
#  ('stomach', 886),
#  ('nyingi', 873),
#  ('nyalo', 871),
#  ('dakika', 867),
#  ('mbili', 864),
#  ('kuzaliwa', 864),
#  ('bado', 864),
#  ('mwisho', 861),
#  ('kwa', 860),
#  ('breathing', 851),
#  ('ask', 847),
#  ('kufura', 844),
#  ('bring', 840),
#  ('kukusaidia', 837),
#  ('wewe', 837),
#  ('coming', 835),
#  ('maumivu', 833),
#  ('wanaweza', 830),
#  ('feeling', 830),
#  ('ujumbe', 817),
#  ('mfupi', 817),
#  ('kula', 816),
#  ('check', 813),
#  ('kulia', 802),
#  ('cord', 791),
#  ('wafanyakazi', 790),
#  ('ujuzi', 790),
#  ('vifaa', 790),
#  ('umeona', 785),
#  ('sometimes', 777),
#  ('where', 777),
#  ('stop', 775),
#  ('messages', 774),
#  ('anaweza', 772),
#  ('crying', 770),
#  ('try', 767),
#  ('method', 767),
#  ('strong', 765),
#  ('feeding', 757),
#  ('kidogo', 754),
#  ('medications', 752),
#  ('minutes', 747),
#  ('vibaya', 746),
#  ('danger', 746),
#  ('effective', 735),
#  ('unajifungua', 734),
#  ('things', 733),
#  ('umekuja', 731),
#  ('good', 726),
#  ('talk', 724),
#  ('kuweka', 722),
#  ('swelling', 722),
#  ('kifafa', 718),
#  ('mradi', 718),
#  ('yeyote', 714),
#  ('umekuwa', 688),
#  ('yellow', 682),
#  ('miguu', 682),
#  ('does', 678),
#  ('komo', 678),
#  ('pains', 666),
#  ('ina', 660),
#  ('wapi', 658),
#  ('signs', 657),
#  ('breath', 657),
#  ('kuumwa', 656),
#  ('kwako', 654),
#  ('manjano', 651),
#  ('assist', 649),
#  ('arrives', 649),
#  ('cry', 648),
#  ('unapaswa', 647),
#  ('tofauti', 646),
#  ('hungry', 645),
#  ('kuom', 644),
#  ('tuko', 639),
#  ('hapa', 639),
#  ('ajili', 639),
#  ('unapojifunguwa', 639),
#  ('tuweze', 639),
#  ('kupumua', 638),
#  ('fast', 636),
#  ('hutokea', 635),
#  ('months', 631),
#  ('dawa', 624),
#  ('mingi', 624),
#  ('face', 621),
#  ('vitu', 619),
#  ('haraka', 615),
#  ('madhara', 612),
#  ('aina', 606),
#  ('sleep', 604),
#  ('chache', 602),
#  ('unasikia', 600),
#  ('osiptal', 598),
#  ('chak', 593),
#  ('infection', 591),
#  ('problem', 588),
#  ('turn', 587),
#  ('worried', 586),
#  ('kusaidia', 585),
#  ('hivi', 585),
#  ('regular', 582),
#  ('kutokwa', 577),
#  ('yote', 577),
#  ('anahitaji', 577),
#  ('kitovu', 573),
#  ('pain', 571),
#  ('stops', 567),
#  ('headache', 564),
#  ('umejifunguwa', 557),
#  ('mengine', 553),
#  ('kazi', 549),
#  ('fluid', 545),
#  ('avoid', 545),
#  ('chandruok', 544),
#  ('usiku', 544),
#  ('bora', 539),
#  ('maambukizi', 538),
#  ('helpful', 537),
#  ('uso', 534),
#  ('skin', 534),
#  ('ako', 532),
#  ('work', 529),
#  ('let', 528),
#  ('bedo', 528),
#  ('mpango', 527),
#  ('start', 524),
#  ('nitie', 523),
#  ('chakula', 520),
#  ('maber', 520),
#  ('miezi', 518),
#  ('has', 518),
#  ('side', 518),
#  ('effects', 518),
#  ('nzuri', 517),
#  ('experience', 517),
#  ('arise', 514),
#  ('require', 514),
#  ('skilled', 514),
#  ('treat', 514),
#  ('without', 514),
#  ('treatment', 514),
#  ('mother', 514),
#  ('die', 514),
#  ('therefore', 514),
#  ('manage', 514),
#  ('arrive', 514),
#  ('familia', 511),
#  ('advice', 511),
#  ('irregular', 510),
#  ('night', 509),
#  ('arm', 503),
#  ('reaching', 502),
#  ('vaccines', 498),
#  ('periods', 498),
#  ('lako', 494),
#  ('hospital', 494),
#  ('sleeping', 494),
#  ('njaa', 492),
#  ('change', 490),
#  ('14', 488),
#  ('years', 486),
#  ('removed', 486),
#  ('punde', 485),
#  ('thank', 485),
#  ('joining', 485),
#  ('reflux', 483),
#  ('polio', 482),
#  ('dpt', 482),
#  ('15', 480),
#  ('normal', 479),
#  ('rocking', 477),
#  ('penjo', 475),
#  ('keeping', 473),
#  ('mwingi', 470),
#  ('mari', 470),
#  ('kujifunguwa', 469),
#  ('difficulty', 468),
#  ('helps', 466),
#  ('sticky', 466),
#  ('vitamins', 466),
#  ('water', 466),
#  ('liquids', 466),
#  ('children', 466),
#  ('chanjo', 466),
#  ('some', 463),
#  ('kutumia', 461),
#  ('thieth', 459),
#  ('there', 458),
#  ('toy', 457),
#  ('skills', 457),
#  ('needed', 457),
#  ('ensure', 457),
#  ('healthy', 457),
#  ('back', 453),
#  ('kutuona', 452),
#  ('tired', 449),
#  ('hours', 448),
#  ('hulala', 447),
#  ('zitaacha', 443),
#  ('dhodho', 441),
#  ('ngozi', 441),
#  ('pneumococcal', 440),
#  ('kaka', 440),
#  ('ne', 438),
#  ('places', 435),
#  ('fontanelles', 435),
#  ('yuko', 432),
#  ('ote', 431),
#  ('hospitalini', 430),
#  ('minute', 430),
#  ('anapozaliwa', 426),
#  ('husaidia', 426),
#  ('vitamini', 426),
#  ('jiepushe', 426),
#  ('vinywaji', 426),
#  ('vingine', 426),
#  ('breast', 426),
#  ('breastfeed', 425),
#  ('moko', 425),
#  ('food', 424),
#  ('akijinyoosha', 424),
#  ('unaumwa', 423),
#  ('mishtuko', 423),
#  ('yanahitaji', 423),
#  ('wenye', 423),
#  ('vya', 423),
#  ('kutibu', 423),
#  ('bila', 423),
#  ('matibabu', 423),
#  ('hayo', 423),
#  ('kufariki', 423),
#  ('ambacho', 423),
#  ('kinaweza', 423),
#  ('kushughulikia', 423),
#  ('utafikaje', 423),
#  ('huwa', 423),
#  ('mpaka', 421),
#  ('huenda', 420),
#  ('haja', 420),
#  ('infections', 420),
#  ('anaonekana', 419),
#  ('unatumia', 418),
#  ('matek', 418),
#  ('unahitaji', 416),
#  ('area', 414),
#  ('asante', 412),
#  ('be', 412),
#  ('karibuni', 409),
#  ('tuangalie', 406),
#  ('wengi', 406),
#  ('mang', 404),
#  ('eny', 404),
#  ('tem', 403),
#  ('kabla', 402),
#  ('tungependa', 402),
#  ('juma', 401),
#  ('umepanga', 398),
#  ('uzaa', 398),
#  ('joma', 395),
#  ('olony', 395),
#  ('umbilical', 395),
#  ('60', 394),
#  ('kulala', 393),
#  ('samoro', 393),
#  ('wachanga', 393),
#  ('protects', 390),
#  ('sindano', 388),
#  ('mabadiliko', 388),
#  ('miaka', 387),
#  ('kuwacha', 387),
#  ('mchana', 387),
#  ('muuguzi', 386),
#  ('tatu', 386),
#  ('uje', 386),
#  ('care', 386),
#  ('kubadilisha', 385),
#  ('remo', 385),
#  ('diaper', 383),
#  ('30', 383),
#  ('antenatal', 382),
#  ('prepare', 382),
#  ('nafasi', 381),
#  ('mkono', 379),
#  ('job', 379),
#  ('yana', 376),
#  ('pus', 376),
#  ('sehemu', 376),
#  ('chake', 376),
#  ('welcome', 375),
#  ('receive', 375),
#  ('weekly', 375),
#  ('support', 375),
#  ('life', 375),
#  ('maen', 374),
#  ('arms', 373),
#  ('legs', 373),
#  ('stimulating', 373),
#  ('tapping', 373),
#  ('foot', 373),
#  ('moves', 373),
#  ('or', 373),
#  ('moving', 373),
#  ('analia', 372),
#  ('kunaweza', 372),
#  ('kutolewa', 370),
#  ('uliza', 370),
#  ('nasi', 369),
#  ('sababu', 367),
#  ('wana', 367),
#  ('vinavyohitajika', 367),
#  ('kuhakikisha', 367),
#  ('unapanga', 367),
#  ('hana', 367),
#  ('mimba', 366),
#  ('ingine', 366),
#  ('mbaya', 363),
#  ('ranyisi', 363),
#  ('to', 362),
#  ('ongea', 361),
#  ('headaches', 361),
#  ('worse', 361),
#  ('sawa', 359),
#  ('onego', 358),
#  ('huduma', 356),
#  ('mag', 351),
#  ('biro', 349),
#  ('kumbembeleza', 347),
#  ('joto', 345),
#  ('dhi', 344),
#  ('fevers', 339),
#  ('karibu', 334),
#  ('utapokea', 334),
#  ('itakusaidia', 334),
#  ('maisha', 334),
#  ('tutumie', 334),
#  ('uuulize', 334),
#  ('mashaka', 334),
#  ('unayo', 334),
#  ('mnaendeleaje', 334),
#  ('tightening', 333),
#  ('regularly', 333),
#  ('leaking', 333),
#  ('contractions', 333),
#  ('unahisije', 333),
#  ('baadhi', 332),
#  ('hupumua', 332),
#  ('kuangalia', 331),
#  ('ng', 329),
#  ('saa', 329),
#  ('ambia', 328),
#  ('wakupeleke', 328),
#  ('wakiona', 328),
#  ('zinaendelea', 328),
#  ('kuzidi', 328),
#  ('service', 327),
#  ('ber', 327),
#  ('nancy', 326),
#  ('ga', 324),
#  ('inyalo', 318),
#  ('mchanga', 317),
#  ('ovyo', 316),
#  ('tukusaidia', 313),
#  ('akicheza', 313),
#  ('delivering', 313),
#  ('kik', 312),
#  ('iwinjo', 312),
#  ('newborns', 310),
#  ('eneo', 308),
#  ('anapaswa', 304),
#  ('unajua', 301),
#  ('pamba', 293),
#  ('ich', 293),
#  ('cleans', 288),
#  ('nguvu', 287),
#  ('unahisi', 287),
#  ('nenda', 287),
#  ('wowowte', 287),
#  ('dry', 286),
#  ('koa', 284),
#  ('umejifungua', 283),
#  ('uko', 283),
#  ('utajifungulia', 283),
#  ('end', 283),
#  ('yie', 282),
#  ('limbe', 281),
#  ('klinik', 278),
#  ('gimoro', 277),
#  ('nyekundu', 276),
#  ('ndalo', 273),
#  ('susan', 270),
#  ('stopping', 268),
#  ('final', 268),
#  ('forward', 268),
#  ('konyi', 268),
#  ('watanyoosha', 266),
#  ('kutingiza', 266),
#  ('hajinyoroshi', 266),
#  ('kuchochea', 266),
#  ('kugusagusa', 266),
#  ('aache', 266),
#  ('baya', 266),
#  ('hayuko', 266),
#  ('hajinyooshi', 266),
#  ('hatari', 266),
#  ('anajinyoosha', 266),
#  ('hold', 265),
#  ('spend', 265),
#  ('playing', 265),
#  ('lay', 265),
#  ('develop', 265),
#  ('muscles', 265),
#  ('crawling', 265),
#  ('development', 265),
#  ('spitting', 265),
#  ('vomiting', 265),
#  ('makes', 265),
#  ('gagging', 265),
#  ('noises', 265),
#  ('uncomfortable', 265),
#  ('smaller', 265),
#  ('feedings', 265),
#  ('upright', 265),
#  ('isseus', 265),
#  ('differently', 264),
#  ('what', 264),
#  ('past', 264),
#  ('did', 264),
#  ('mwili', 263),
#  ('mothers', 263),
#  ('sad', 263),
#  ('anxious', 263),
#  ('idhi', 263),
#  ('ibiro', 262),
#  ('common', 261),
#  ('wrong', 261),
#  ('poo', 261),
#  ('fussy', 261),
#  ('molony', 261),
#  ('yore', 261),
#  ('distressing', 260),
#  ('parents', 260),
#  ('cries', 260),
#  ('long', 260),
#  ('late', 260),
#  ('afternoon', 260),
#  ('evening', 260),
#  ('colic', 260),
#  ('lying', 260),
#  ('lap', 260),
#  ('tummy', 260),
#  ('rub', 260),
#  ('exeprience', 260),
#  ('body', 259),
#  ('adjust', 259),
#  ('usually', 259),
#  ('subside', 259),
#  ('before', 259),
#  ('nurses', 259),
#  ('chosen', 259),
#  ('nikech', 259),
#  ('sharon', 258),
#  ('mary', 257),
#  ('amelala', 256),
#  ('until', 256),
#  ('reaches', 256),
#  ('fever', 256),
#  ('appretite', 256),
#  ('fatigued', 256),
#  ('give', 256),
#  ('medication', 256),
#  ('talking', 256),
#  ('seche', 253),
#  ('age', 251),
#  ('smiling', 251),
#  ('putting', 251),
#  ('rattle', 251),
#  ('grasp', 251),
#  ('space', 251),
#  ('think', 251),
#  ('options', 251),
#  ('choice', 251),
#  ('can', 251),
#  ('due', 249),
#  ('received', 249),
#  ('injection', 249),
#  ('works', 249),
#  ('predicatable', 249),
#  ('challenges', 249),
#  ('ann', 248),
#  ('soft', 247),
#  ('skull', 247),
#  ('bones', 247),
#  ('fused', 247),
#  ('nature', 247),
#  ('allowing', 247),
#  ('pass', 247),
#  ('canal', 247),
#  ('fontanelle', 247),
#  ('sunken', 247),
#  ('dehydration', 247),
#  ('they', 247),
#  ('bulge', 247),
#  ('slightly', 247),
#  ('return', 247),
#  ('doctor', 247),
#  ('chenro', 247),
#  ('wan', 246),
#  ('checking', 246),
#  ('wakonyi', 245),
#  ('ibi', 244),
#  ('easy', 243),
#  ('put', 243),
#  ('kutoka', 238),
#  ('husafisha', 238),
#  ('starting', 238),
#  ('cotton', 238),
#  ('wool', 238),
#  ('clothes', 238),
#  ('over', 237),
#  ('send', 237),
#  ('decisions', 237),
#  ('spacing', 237),
#  ('future', 237),
#  ('jinsi', 237),
#  ('ariyo', 235),
#  ('violet', 235),
#  ('konyo', 234),
#  ('imi', 232),
#  ('lot', 231),
#  ('wo', 231),
#  ('stay', 231),
#  ('asleep', 231),
#  ('feed', 231),
#  ('comfort', 231),
#  ('take', 231),
#  ('naps', 231),
#  ('interact', 231),
#  ('dark', 231),
#  ('quiet', 231),
#  ('daktari', 231),
#  ('unaeza', 229),
#  ('kuanza', 229),
#  ('nguo', 229),
#  ('zako', 229),
#  ('madawa', 229),
#  ('unayohitaji', 229),
#  ('swali', 229),
#  ('utakavyo', 229),
#  ('navyo', 229),
#  ('ipango', 229),
#  ('kuot', 228),
#  ('grunting', 227),
#  ('nose', 227),
#  ('flares', 227),
#  ('wheezing', 227),
#  ('notice', 227),
#  ('issues', 227),
#  ('unatokwa', 227),
#  ('manufaa', 223),
#  ('nigi', 221),
#  ('utone', 220),
#  ('akifikisha', 220),
#  ('tujulisha', 220),
#  ('ushirikiano', 220),
#  ('wetu', 220),
#  ('umekuwaje', 220),
#  ('umekusaidia', 220),
#  ('tunatarajia', 220),
#  ('kukuona', 220),
#  ('inyiswa', 220),
#  ('iye', 219),
#  ('anatoa', 218),
#  ('mate', 218),
#  ('kutapika', 218),
#  ('hahisi', 218),
#  ('kumpa', 218),
#  ('kumkalisha', 218),
#  ('noted', 218),
#  ('convulsions', 218),
#  ('by', 217),
#  ('typical', 217),
#  ('newborn', 217),
#  ('soiled', 217),
#  ('pay', 217),
#  ('attention', 217),
#  ('soothes', 217),
#  ('singing', 217),
#  ('swaddling', 217),
#  ('sucking', 217),
#  ('wuok', 217),
#  ('gik', 216),
#  ('feet', 216),
#  ('message', 216),
#  ('program', 216),
#  ('schedule', 216),
#  ('irene', 216),
#  ('ameanza', 215),
#  ('kusimamisha', 215),
#  ('mwentewe', 215),
#  ('tenga', 215),
#  ('ucheze', 215),
#  ('akiwa', 215),
#  ('amealala', 215),
#  ('itawasaidia', 215),
#  ('kujenga', 215),
#  ('misuli', 215),
#  ('inayohitajika', 215),
#  ('kutambaa', 215),
#  ('fanya', 215),
#  ('maendeleo', 215),
#  ('dwaro', 215),
#  ('rem', 215),
#  ('faster', 215),
#  ('older', 215),
#  ('count', 215),
#  ('number', 215),
#  ('breaths', 215),
#  ('mbinu', 214),
#  ('zakupanga', 214),
#  ('zipi', 214),
#  ('umewahi', 214),
#  ('awali', 214),
#  ('ulizipenda', 214),
#  ('kuzitumia', 214),
#  ('enjoy', 214),
#  ('learn', 214),
#  ('signals', 214),
#  ('sleepy', 214),
#  ('suck', 214),
#  ('smack', 214),
#  ('lips', 214),
#  ('bottle', 214),
#  ('pattern', 214),
#  ('wamama', 212),
#  ('kuhisi', 212),
#  ('huzuni', 212),
#  ('kusababisha', 212),
#  ('ugumu', 212),
#  ('infant', 212),
#  ('breastfed', 212),
#  ('month', 212),
#  ('mabiro', 211),
#  ('anaenda', 210),
#  ('anasumbua', 210),
#  ('usaidizi', 210),
#  ('ineno', 210),
#  ('mpangilio', 209),
#  ('unanyonyesha', 209),
#  ('zingine', 209),
#  ('haimaanishi', 209),
#  ('kitu', 209),
#  ('changamoto', 209),
#  ('bang', 209),
#  ('isekonyori', 208),
#  ('prevent', 208),
#  ('washing', 208),
#  ('clean', 208),
#  ('stump', 207),
#  ('fall', 207),
#  ('painful', 207),
#  ('red', 207),
#  ('smelly', 207),
#  ('discharge', 207),
#  ('healing', 207),
#  ('wazazi', 206),
#  ('mrefu', 206),
#  ('haswa', 206),
#  ('jioni', 206),
#  ('anaumwa', 206),
#  ('kumlaza', 206),
#  ('paja', 206),
#  ('kumsugua', 206),
#  ('mgongo', 206),
#  ('kumtuliza', 206),
#  ('ukiwa', 206),
#  ('umebeba', 206),
#  ('ushauri', 206),
#  ('ukianza', 204),
#  ('kuchukua', 204),
#  ('kuzoea', 204),
#  ('hizi', 204),
#  ('huisha', 204),
#  ('wajulishe', 204),
#  ('wauguzi', 204),
#  ('umechagua', 204),
#  ('kanye', 204),
#  ('nyuolo', 203),
#  ('heavy', 203),
#  ('severe', 203),
#  ('ipek', 202),
#  ('akifikia', 201),
#  ('kumleta', 201),
#  ('homa', 201),
#  ('hamu', 201),
#  ('dhaifu', 201),
#  ('kutompa', 201),
#  ('kuzungumza', 201),
#  ('chochote', 201),
#  ('kupa', 201),
#  ('wabiro', 200),
#  ('kare', 200),
#  ('lilian', 200),
#  ('purity', 199),
#  ('muhimu', 198),
#  ('kati', 198),
#  ('fikiria', 198),
#  ('chaguo', 198),
#  ('ijayo', 198),
#  ('tunaweza', 198),
#  ('mawaidha', 198),
#  ('yudo', 198),
#  ('marach', 196),
#  ('umri', 195),
#  ('kutabasu', 195),
#  ('kufikia', 195),
#  ('shaker', 195),
#  ('kuona', 195),
#  ('atafanya', 195),
#  ('anafikia', 195),
#  ('piny', 195),
#  ('achieng', 195),
#  ('umetumia', 194),
#  ('hufanya', 194),
#  ('hupata', 194),
#  ('mara', 194),
#  ('hutaki', 194),
#  ('sio', 194),
#  ('abnormal', 194),
#  ('movement', 194),
#  ('jerking', 194),
#  ('stiffening', 194),
#  ('active', 194),
#  ('chupa', 194),
#  ('amefikisha', 191),
#  ('kupewa', 191),
#  ('amepokea', 191),
#  ('ndiyo', 189),
#  ('kwetu', 189),
#  ('unarudi', 189),
#  ('lini', 189),
#  ('tupange', 189),
#  ('utuone', 189),
#  ('ban', 189),
#  ('makuongo', 189),
#  ('mopoto', 189),
#  ('maraton', 189),
#  ('dhadhu', 189),
#  ('pi', 189),
#  ('mimadho', 189),
#  ('huzuia', 188),
#  ('kutokana', 188),
#  ('magonjwa', 188),
#  ('one', 188),
#  ('redness', 188),
#  ('smell', 188),
#  ('rashes', 188),
#  ('laini', 188),
#  ('ambako', 188),
#  ('mifupa', 188),
#  ('fuvu', 188),
#  ('haijaunganishwa', 188),
#  ('asili', 188),
#  ('kuruhusu', 188),
#  ('kupita', 188),
#  ('kupumulia', 188),
#  ('imeingia', 188),
#  ('kutokuwa', 188),
#  ('mwilini', 188),
#  ('akilia', 188),
#  ('inapaswa', 188),
#  ('kurudi', 188),
#  ('anaacha', 188),
#  ('sivyo', 188),
#  ('mpeleke', 188),
#  ('inaufanisi', 186),
#  ('rahisi', 186),
#  ('yaweza', 186),
#  ('anayetumia', 186),
#  ('inawekwa', 184),
#  ('ufanisi', 184),
#  ('mitatu', 184),
#  ('unaswali', 184),
#  ('adek', 183),
#  ('zijazo', 183),
#  ('tutakutumia', 183),
#  ('ambao', 183),
#  ('utakusaidia', 183),
#  ('kufanya', 183),
#  ('uamuzi', 183),
#  ('katikati', 183),
#  ('usoni', 183),
#  ('unanapanga', 183),
#  ('kusikia', 182),
#  ('uchovu', 182),
#  ('just', 182),
#  ('reminder', 182),
#  ('respond', 182),
#  ('nights', 182),
#  ('weekends', 182),
#  ('kukumbusha', 182),
#  ('haziwezi', 182),
#  ('kujibwa', 182),
#  ('wikendi', 182),
#  ('chopo', 181),
#  ('nyithindo', 181),
#  ('hawawezi', 181),
#  ('kadhaa', 181),
#  ('kulisha', 181),
#  ('lala', 181),
#  ('analala', 181),
#  ('ushirikiane', 181),
#  ('utulivu', 181),
#  ('giza', 181),
#  ('hulalaje', 181),
#  ('janet', 181),
#  ('kuuliza', 180),
#  ('makamagi', 179),
#  ('wanapumwa', 179),
#  ('mlio', 179),
#  ('kifua', 179),
#  ('pua', 179),
#  ('zao', 179),
#  ('zinpanuka', 179),
#  ('kutoa', 179),
#  ('kifuani', 179),
#  ('wanapopumuwa', 179),
#  ('unaona', 179),
#  ('masuala', 179),
#  ('immediately', 178),
#  ('illness', 178),
#  ('ulimpeleka', 176),
#  ('kuangaliwa', 176),
#  ('kujdiffcultyua', 175),
#  ('ruth', 175),
#  ('akinyi', 175),
#  ('sarah', 174),
#  ('nibrenda', 173),
#  ('yor', 172),
#  ('weight', 172),
#  ('esther', 170),
#  ('mine', 169),
#  ('yuak', 169),
#  ('nas', 168),
#  ('ngima', 167),
#  ('chuer', 167),
#  ('masaa', 166),
#  ('mawili', 166),
#  ('machovu', 166),
#  ('chafu', 166),
#  ('jihadharini', 166),
#  ...]

# %%
# Prepare training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X_bow, y, test_size=0.10, train_size=0.90, random_state=55)

# %%
logreg = sklearn.linear_model.LogisticRegression(solver='lbfgs', max_iter=570)
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=570, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
prediction = logreg.predict(X_test)
pr = logreg.predict_proba(X_test)
plt.hist(pr[:,0])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
A = np.random.normal(size=(3, 6))
B = np.random.normal(size=(3, 2))
np.hstack([A, B]).shape
# Out:
# (3, 8)

# %%
#1. accuracy_score
accuracy_score(y_test, prediction)
# Out:
# 0.6895889358432578

# %%
#Let's also do roc-auc-score
roc_auc_score(y_test, pr[:,1])
# Out:
# 0.7588905871478713

# %%
all_features = np.hstack((X_bow.todense(),
                      systemMessagesDF[['edd_wk','study_wk', 'past_response',
                                        'native_langauge','delivery_status',
                                        'swahili', 'english', 'luo']].values.astype(np.float32)))

# %%
X_bow.shape
# Out:
# (26021, 2105)

# %%
systemMessagesDF.shape
# Out:
# (26021, 27)

# %%
X_train, X_test, y_train, y_test = train_test_split(all_features, y, test_size=0.10, train_size=0.90, random_state=55)

# %%
logreg = sklearn.linear_model.LogisticRegression(solver='lbfgs', max_iter=2000) # try sklearn.linear_model.ElasticNetCV
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=2000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
prediction = logreg.predict(X_test)
pr = logreg.predict_proba(X_test)
plt.hist(pr[:,0])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
#1. accuracy_score
accuracy_score(y_test, prediction)
# Out:
# 0.7191701882443334

# %%
#Let's also do roc-auc-score
roc_ = roc_auc_score(y_test, pr[:,1])

# %%
# Let's see the results visually 
fpr, tpr, thresholds = roc_curve(y_test, pr[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % roc_)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# # Predictions using Bigrams and Logistic Regression

# %%
bigram_allfeatures = np.hstack((X_ngram.todense(),
                      systemMessagesDF[['edd_wk','study_wk', 'past_response',
                                        'native_langauge','delivery_status',
                                        'swahili', 'english', 'luo']].values.astype(np.float32)))

# %%
xtrain, xtest, ytrain, ytest = train_test_split(bigram_allfeatures, y, test_size=0.20, random_state=60)

# %%
#Fitting the model
#Note: Its taking long to converge, perhaps we should consider scaling some features like chars, words
model = sklearn.linear_model.LogisticRegression(solver='lbfgs', max_iter=5000)
model.fit(xtrain, ytrain)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=5000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
#Lets visualize some test predictions.
pred = model.predict_proba(xtest)
plt.hist(pred[:,0])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
#lets measure the performance of this model
#accuracy_score
predicted = model.predict(xtest)
accuracy_score(ytest, predicted)
# Out:
# 0.7465898174831892

# %%
#Let's also do roc-auc-score
roc_ = roc_auc_score(ytest, pred[:,1])
roc_
# Out:
# 0.8220992154994785

# %%
# Let's see the results visually
# logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test)) 
fpr, tpr, thresholds = roc_curve(ytest, pred[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % roc_)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# # Predictions using bigrams and gradient boosting

# %%
model = sklearn.ensemble.GradientBoostingClassifier()
model.fit(xtrain, ytrain)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
prediction = model.predict(xtest)
pr = model.predict_proba(xtest)
plt.hist(pr[:,0])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
#lets measure the performance of this model
#accuracy_score
accuracy_score(ytest, prediction)
# Out:
# 0.709702209414025

# %%
#Let's also do roc-auc-score
roc_ = roc_auc_score(ytest, pr[:,1])
roc_
# Out:
# 0.7751351104278907

# %%
# Let's see the results visually
# logit_roc_auc = roc_auc_score(y_test, logreg.predict(X_test)) 
fpr, tpr, thresholds = roc_curve(ytest, pr[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % roc_)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
#plt.savefig('Log_ROC')
plt.show()
