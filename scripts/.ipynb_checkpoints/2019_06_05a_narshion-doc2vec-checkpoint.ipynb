# %% [markdown]
# # Predictions using Gensim doc2vec and Logistic regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.model_selection import RepeatedKFold
import sklearn.ensemble
import statistics

pd.set_option('display.max_rows', 4)

# %%
# !date

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
#     Load the dataset and create a corpus text

# %%
messages_df = pd.read_excel("/home/j/Project/Models/NLP/mWACH/MobileWACH_Neo_messages_export_2019-03-05.xlsx")
messages_df
# Out:
#          mid  pid  day               timestamp                     auto  \
# 0        808   15  Tue 2017-12-05 06:36:59.614  signup.two-way.normal.0
# 1        859   15  Tue 2017-12-05 06:55:45.982                      NaN
# ...      ...  ...  ...                     ...                      ...
# 59504  56843  800  Sun 2018-07-15 17:05:23.401    edd.two-way.normal.14
# 59505  67270  800  Mon 2019-02-04 06:31:09.703                      NaN
#
#       external   delta_human         delta  delta_last   study_wk     edd_wk  \
# 0      Success           NaN           NaN         NaN   0.000000  -9.000000
# 1          NaN          18m   1.126367e+03         NaN   0.000000  -9.000000
# ...        ...           ...           ...         ...        ...        ...
# 59504   Failed           NaN           NaN         NaN   8.714286   2.000000
# 59505   Failed  258d 20h 7m   2.236368e+07         NaN  37.857143  31.142857
#
#        chars  words       topic  related      sent_by language  \
# 0        250     42         NaN      NaN       system  swahili
# 1         30      4  validation      1.0  participant  english
# ...      ...    ...         ...      ...          ...      ...
# 59504    252     41    42 weeks      NaN       system  swahili
# 59505    354     58         NaN      NaN        nurse      NaN
#
#                                               translated  \
# 0      Welcome to Mobile WACh NEO! Good job coming in...
# 1                                                    NaN
# ...                                                  ...
# 59504  {name}, this is {nurse} from {clinic} Bad swel...
# 59505  {name}, this is {nurse} from {clinic}. Thank y...
#
#                                                 original
# 0      Karibu kwa Mobile WACh NEO. Kazi nzuri kwa kuj...
# 1                         Validation Code Correct: 13514
# ...                                                  ...
# 59504  Linet, huyu ni Mercy kutoka Rachuonyo. kufura ...
# 59505  Linet, huyu ni Mercy kutoka kwa Rachuonyo. Asa...
#
# [59506 rows x 19 columns]

# %%
# #Load participant data
# p_data = pd.io.stata.read_stata('C:/Users/user/UW/keshet - mwach_interaction/ParticipantData/mwachNeo/NEO_Enrollment_Interview.dta')
# p_data

# %%
# for col in p_data.columns: 
#     print(col)

# %%
# age in years as continuous outcome to predict
messages_df['system_msg'] = (messages_df['sent_by']=='system')

# %%
messages_df = messages_df[messages_df.sent_by != 'nurse']

# %%
#We need to know number of responses each system message received. --- we will come back later to remove nurse messages
messages_df['msg_group'] = messages_df.system_msg.cumsum()
messages_df.msg_group.value_counts()
# Out:
# /share/code/abie/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 7115     114
# 24446     23
#         ...
# 9385       1
# 2047       1
# Name: msg_group, Length: 26021, dtype: int64

# %%
#Our responses vector is all those messages with a value count of more than 1
response = (messages_df.msg_group.value_counts() > 1)#Creating the systemMessage DataFrame to define our features.
systemMesaagesDF = messages_df[messages_df.sent_by == "system"]
systemMesaagesDF = systemMesaagesDF.set_index('msg_group')
systemMesaagesDF['response'] = response
systemMesaagesDF['swahili'] = systemMesaagesDF.language == 'swahili'
systemMesaagesDF['english'] = systemMesaagesDF.language == 'english'
systemMesaagesDF['luo'] = systemMesaagesDF.language == 'luo'
systemMesaagesDF.shape
# Out:
# (26021, 24)

# %%
#Let's now filter the columns and convert them to float.
X = systemMesaagesDF.filter(['edd_wk', 'chars', 'words', 'swahili', 'english', 'luo']).astype(np.float)
y = systemMesaagesDF.response.astype(np.float)
# convert to numpy arrays (pandas and sklearn don't always work together well)
y = y.values

# %%
#Lets create our text corpus
X_text = systemMesaagesDF.translated.astype('str')
corpus = X_text.values
corpus
# Out:
# array(["Welcome to Mobile WACh NEO! Good job coming in for your visit! You will receive weekly SMS to help support you during pregnancy and during the first months of your baby's life. Please SMS back and tell us any questions or concerns you have.",
#        '{name}, this is {nurse} from {clinic}. Sometimes problems arise during labour and delivery, like bleeding or fits, which require skilled health workers, medications and equipment to treat. Without that treatment, the mother and baby could die. Therefore it is safest to deliver in a facility that can manage these and other problems. How will you arrive at the facility?',
#        '{name}, this is {nurse} from {clinic} Bad swelling of hands and face or a bad headache are signs of a problem. Ask your family to take you to the clinic if they see this. Have you had any swelling or headaches during pregnancy? Are they getting worse?',
#        ...,
#        '{name}, this is {nurse} from {clinic}. Breastfeeding a baby immediately after birth helps the milk come. The first yellow sticky milk has many vitamins & protects the baby from illness. Milk has all the water the baby needs, avoid other liquids. Are you planning to breastfeed?',
#        '{name}, this is {nurse} from {clinic}. Have you had your baby? We are here for you. Please let us know as soon as you deliver so we can assist you after the baby arrives.',
#        '{name}, this is {nurse} from {clinic} Bad swelling of hands and face or a bad headache are signs of a problem. Ask your family to take you to the clinic if they see this. Have you had any swelling or headaches during pregnancy? Are they getting worse?'],
#       dtype=object)

# %%
y
# Out:
# array([1., 1., 1., ..., 0., 0., 0.])

# %%
# instead of encoding the text data with an n-gram, in this notebook we will use doc2vec to embed the
# text in a high-dimensional vector

# see https://radimrehurek.com/gensim/models/doc2vec.html for documentation

from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from nltk.tokenize import word_tokenize

# %%
# tagged_data = [TaggedDocument(words=word_tokenize(_d.lower()), tags=[str(i)]) for i, _d in enumerate(data)]

documents = [TaggedDocument(doc.lower(), [i]) for i, doc in enumerate(X_text)]

# %%
documents
# Out:
# [TaggedDocument(words="welcome to mobile wach neo! good job coming in for your visit! you will receive weekly sms to help support you during pregnancy and during the first months of your baby's life. please sms back and tell us any questions or concerns you have.", tags=[0]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. sometimes problems arise during labour and delivery, like bleeding or fits, which require skilled health workers, medications and equipment to treat. without that treatment, the mother and baby could die. therefore it is safest to deliver in a facility that can manage these and other problems. how will you arrive at the facility?', tags=[1]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic} bad swelling of hands and face or a bad headache are signs of a problem. ask your family to take you to the clinic if they see this. have you had any swelling or headaches during pregnancy? are they getting worse?', tags=[2]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. breastfeeding a baby right after birth helps the milk come. the first yellow sticky milk has many vitamins & cleans out the stomach. milk has all the water the baby needs, avoid other liquids. are you planning to breastfeed?', tags=[3]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}
),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. family planning methods work differently for different women. what methods have you used in the past? did you like these methods? do you plan to use them again?', tags=[24]),
#  TaggedDocument(words="{name}, this is {nurse} from {clinic}. your baby may be trying to hold up their head. spend a few minutes each day playing while they lay on their stomach. this will help them develop muscles they need to start crawling. work up to 15 minutes a day. do you have any questions about your baby's development?", tags=[25]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. if your baby has frequent spitting up or vomiting, makes gagging noises and seems uncomfortable, this may be reflux. smaller more frequent feedings and keeping the baby upright after feeding can help. is your baby having any isseus with feeding?', tags=[26]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. this week our messages will be stopping. please come in for your final visit with us when your baby is about 14 weeks old. let us know if you have any difficulty coming in. we would like to know your experience with us and if this service has been helpful. we look forward to seeing you.', tags=[27]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. thank you for joining us in mobile wach neo. the messages will stop soon though you can still ask questions. has this been helpful for you are your baby?', tags=[28]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. thank you for joining us in mobile wach neo. this is the last message from us. please be sure to come and see us for your last program visit! when is your next visit? please let us know so we can schedule you to come in to see us.', tags=[29]),
#  TaggedDocument(words='nan', tags=[30]),
#  TaggedDocument(words='nan', tags=[31]),
#  TaggedDocument(words='nan', tags=[32]),
#  TaggedDocument(words='nan', tags=[33]),
#  TaggedDocument(words='nan', tags=[34]),
#  TaggedDocument(words='nan', tags=[35]),
#  TaggedDocument(words='nan', tags=[36]),
#  TaggedDocument(words='nan', tags=[37]),
#  TaggedDocument(words='nan', tags=[38]),
#  TaggedDocument(words='nan', tags=[39]),
#  TaggedDocument(words='nan', tags=[40]),
#  TaggedDocument(words='nan', tags=[41]),
#  TaggedDocument(words='nan', tags=[42]),
#  TaggedDocument(words='nan', tags=[43]),
#  TaggedDocument(words='nan', tags=[44]),
#  TaggedDocument(words='nan', tags=[45]),
#  TaggedDocument(words='nan', tags=[46]),
#  TaggedDocument(words='nan', tags=[47]),
#  TaggedDocument(words='nan', tags=[48]),
#  TaggedDocument(words='nan', tags=[49]),
#  TaggedDocument(words='nan', tags=[50]),
#  TaggedDocument(words='nan', tags=[51]),
#  TaggedDocument(words='nan', tags=[52]),
#  TaggedDocument(words='nan', tags=[53]),
#  TaggedDocument(words='nan', tags=[54]),
#  TaggedDocument(words='nan', tags=[55]),
#  TaggedDocument(words='nan', tags=[56]),
#  TaggedDocument(words='nan', tags=[57]),
#  TaggedDocument(words='nan', tags=[58]),
#  TaggedDocument(words='nan', tags=[59]),
#  TaggedDocument(words='nan', tags=[60]),
#  TaggedDocument(words='nan', tags=[61]),
#  TaggedDocument(words='nan', tags=[62]),
#  TaggedDocument(words='nan', tags=[63]),
#  TaggedDocument(words='nan', tags=[64]),
#  TaggedDocument(words="welcome to mobile wach neo! good job coming in for your visit! you will receive weekly sms to help support you during pregnancy and during the first months of your baby's life. please sms back and tell us any questions or concerns you have.", tags=[65]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. sometimes problems arise during labour and delivery, like bleeding or fits, which require skilled health workers, medications and equipment to treat. without that treatment, the mother and baby could die. therefore it is safest to deliver in a facility that can manage these and other problems. how will you arrive at the facility?', tags=[66]),
#  TaggedDocument(words='{name}, this is {nurse} from {clin
),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. thank you for joining us in mobile wach neo. this is the last message from us. please be sure to come and see us for your last program visit! when is your next visit? please let us know so we can schedule you to come in to see us.', tags=[104]),
#  TaggedDocument(words='nan', tags=[105]),
#  TaggedDocument(words='nan', tags=[106]),
#  TaggedDocument(words='nan', tags=[107]),
#  TaggedDocument(words='nan', tags=[108]),
#  TaggedDocument(words='nan', tags=[109]),
#  TaggedDocument(words='nan', tags=[110]),
#  TaggedDocument(words='nan', tags=[111]),
#  TaggedDocument(words='nan', tags=[112]),
#  TaggedDocument(words='nan', tags=[113]),
#  TaggedDocument(words='nan', tags=[114]),
#  TaggedDocument(words='nan', tags=[115]),
#  TaggedDocument(words='nan', tags=[116]),
#  TaggedDocument(words='nan', tags=[117]),
#  TaggedDocument(words='nan', tags=[118]),
#  TaggedDocument(words='nan', tags=[119]),
#  TaggedDocument(words='nan', tags=[120]),
#  TaggedDocument(words='nan', tags=[121]),
#  TaggedDocument(words='nan', tags=[122]),
#  TaggedDocument(words='nan', tags=[123]),
#  TaggedDocument(words='nan', tags=[124]),
#  TaggedDocument(words='nan', tags=[125]),
#  TaggedDocument(words='nan', tags=[126]),
#  TaggedDocument(words='nan', tags=[127]),
#  TaggedDocument(words='nan', tags=[128]),
#  TaggedDocument(words='nan', tags=[129]),
#  TaggedDocument(words='nan', tags=[130]),
#  TaggedDocument(words='nan', tags=[131]),
#  TaggedDocument(words='nan', tags=[132]),
#  TaggedDocument(words='nan', tags=[133]),
#  TaggedDocument(words='nan', tags=[134]),
#  TaggedDocument(words='nan', tags=[135]),
#  TaggedDocument(words='nan', tags=[136]),
#  TaggedDocument(words='nan', tags=[137]),
#  TaggedDocument(words='nan', tags=[138]),
#  TaggedDocument(words='nan', tags=[139]),
#  TaggedDocument(words='nan', tags=[140]),
#  TaggedDocument(words='nan', tags=[141]),
#  TaggedDocument(words='nan', tags=[142]),
#  TaggedDocument(words='nan', tags=[143]),
#  TaggedDocument(words='nan', tags=[144]),
#  TaggedDocument(words='nan', tags=[145]),
#  TaggedDocument(words='nan', tags=[146]),
#  TaggedDocument(words='nan', tags=[147]),
#  TaggedDocument(words='nan', tags=[148]),
#  TaggedDocument(words='nan', tags=[149]),
#  TaggedDocument(words='nan', tags=[150]),
#  TaggedDocument(words='nan', tags=[151]),
#  TaggedDocument(words='nan', tags=[152]),
#  TaggedDocument(words='nan', tags=[153]),
#  TaggedDocument(words='nan', tags=[154]),
#  TaggedDocument(words='nan', tags=[155]),
#  TaggedDocument(words='nan', tags=[156]),
#  TaggedDocument(words='nan', tags=[157]),
#  TaggedDocument(words='nan', tags=[158]),
#  TaggedDocument(words='nan', tags=[159]),
#  TaggedDocument(words='nan', tags=[160]),
#  TaggedDocument(words='nan', tags=[161]),
#  TaggedDocument(words='nan', tags=[162]),
#  TaggedDocument(words='nan', tags=[163]),
#  TaggedDocument(words='nan', tags=[164]),
#  TaggedDocument(words='nan', tags=[165]),
#  TaggedDocument(words='nan', tags=[166]),
#  TaggedDocument(words='nan', tags=[167]),
#  TaggedDocument(words='nan', tags=[168]),
#  TaggedDocument(words='nan', tags=[169]),
#  TaggedDocument(words='nan', tags=[170]),
#  TaggedDocument(words='nan', tags=[171]),
#  TaggedDocument(words='nan', tags=[172]),
#  TaggedDocument(words='nan', tags=[173]),
#  TaggedDocument(words='nan', tags=[174]),
#  TaggedDocument(words='nan', tags=[175]),
#  TaggedDocument(words='nan', tags=[176]),
#  TaggedDocument(words='nan', tags=[177]),
#  TaggedDocument(words='nan', tags=[178]),
#  TaggedDocument(words='nan', tags=[179]),
#  TaggedDocument(words='nan', tags=[180]),
#  TaggedDocument(words='nan', tags=[181]),
#  TaggedDocument(words='nan', tags=[182]),
#  TaggedDocument(words='nan', tags=[183]),
#  TaggedDocument(words='nan', tags=[184]),
#  TaggedDocument(words='nan', tags=[185]),
#  TaggedDocument(words='nan', tags=[186]),
#  TaggedDocument(words='nan', tags=[187]),
#  TaggedDocument(words='nan', tags=[188]),
#  TaggedDocument(words='nan', tags=[189]),
#  TaggedDocument(words='nan', tags=[190]),
#  TaggedDocument(words='nan', tags=[191]),
#  TaggedDocument(words='nan', tags=[192]),
#  TaggedDocument(words='nan', tags=[193]),
#  TaggedDocument(words='nan', tags=[194]),
#  TaggedDocument(words='nan', tags=[195]),
#  TaggedDocument(words='nan', tags=[196]),
#  TaggedDocument(words='nan', tags=[197]),
#  TaggedDocument(words="welcome to mobile wach neo! good job coming in for your visit! you will receive weekly sms to help support you during pregnancy and during the first months of your baby's life. please sms back and tell us any questions or concerns you have.", tags=[198]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. breastfeeding a baby right after birth helps the milk come. the first yellow sticky milk has many vitamins & cleans out the stomach. milk has all the water the baby needs, avoid other liquids. are you planning to breastfeed?', tags=[199]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. make sure you come in 4 times for antenatal care. we check your blood to see if it is strong, check for any problems and help you prepare a birth plan. the 4th visit includes checking that the baby is in a good position. do you have any questions or concerns? are you feeling the baby move often?', tags=[200]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. it is safest for all women to deliver in a health facility because health workers have the skills and equipment needed to help ensure a safe delivery and a healthy baby. where do you plan to deliver?', tags=[201]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. sometimes problems arise during labour and delivery, like bleeding or fits, which require skilled health workers, medications and equipment to treat. without that treatment, the mother and baby could die. therefore it is safest to deliver in a facility that can manage these and other problems. how will you arrive at the facility?', tags=[202]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. regular, strong stomach pains are a sign of labour. if you feel this strong tightening regularly pains, leaking of fluid or bleeding, go to the facility. do you feel any contractions? do you have any concerns?', tags=[203]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? please let us know if you are having any problems. where are you delivering your baby?', tags=[204]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? we are here for you. please let us know as soon as you deliver so we can assist you after the baby arrives.', tags=[205]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. you should be starting labour soon. make sure to bring cotton wool , clothes for you and the baby and any medications you need to the hospital. do you have any questions about what to bring?', tags=[206]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? we are here for you. please let us know as soon as you deliver so we can assist you after the baby arrives.', tags=[207]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. breastfeeding a baby immediately after birth helps the milk come. the first yellow sticky milk has many vitamins & protects the baby from illness. milk has all the water the baby needs, avoid other liquids. are you planning to breastfeed?', tags=[208]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? we are here for you. please let us know as soon as you deliver so we can assist you after the baby arrives.', tags=[209]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}
),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. make sure you come in 4 times for antenatal care. we check your blood to see if it is strong, check for any problems and help you prepare a birth plan. the 4th visit includes checking that the baby is in a good position. do you have any questions or concerns? are you feeling the baby move often?', tags=[246]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. it is safest for all women to deliver in a health facility because health workers have the skills and equipment needed to help ensure a safe delivery and a healthy baby. where do you plan to deliver?', tags=[247]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. sometimes problems arise during labour and delivery, like bleeding or fits, which require skilled health workers, medications and equipment to treat. without that treatment, the mother and baby could die. therefore it is safest to deliver in a facility that can manage these and other problems. how will you arrive at the facility?', tags=[248]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. regular, strong stomach pains are a sign of labour. if you feel this strong tightening regularly pains, leaking of fluid or bleeding, go to the facility. do you feel any contractions? do you have any concerns?', tags=[249]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? please let us know if you are having any problems. where are you delivering your baby?', tags=[250]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? we are here for you. please let us know as soon as you deliver so we can assist you after the baby arrives.', tags=[251]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. you should be starting labour soon. make sure to bring cotton wool , clothes for you and the baby and any medications you need to the hospital. do you have any questions about what to bring?', tags=[252]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? we are here for you. please let us know as soon as you deliver so we can assist you after the baby arrives.', tags=[253]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. breastfeeding a baby immediately after birth helps the milk come. the first yellow sticky milk has many vitamins & protects the baby from illness. milk has all the water the baby needs, avoid other liquids. are you planning to breastfeed?', tags=[254]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? we are here for you. please let us know as soon as you deliver so we can assist you after the baby arrives.', tags=[255]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic} bad swelling of hands and face or a bad headache are signs of a problem. ask your family to take you to the clinic if they see this. have you had any swelling or headaches during pregnancy? are they getting worse?', tags=[256]),
#  TaggedDocument(words='nan', tags=[257]),
#  TaggedDocument(words='nan', tags=[258]),
#  TaggedDocument(words='nan', tags=[259]),
#  TaggedDocument(words='nan', tags=[260]),
#  TaggedDocument(words='nan', tags=[261]),
#  TaggedDocument(words='nan', tags=[262]),
#  TaggedDocument(words='nan', tags=[263]),
#  TaggedDocument(words='nan', tags=[264]),
#  TaggedDocument(words='nan', tags=[265]),
#  TaggedDocument(words='nan', tags=[266]),
#  TaggedDocument(words='nan', tags=[267]),
#  TaggedDocument(words='nan', tags=[268]),
#  TaggedDocument(words='nan', tags=[269]),
#  TaggedDocument(words='nan', tags=[270]),
#  TaggedDocument(words='nan', tags=[271]),
#  TaggedDocument(words='nan', tags=[272]),
#  TaggedDocument(words='nan', tags=[273]),
#  TaggedDocument(words='nan', tags=[274]),
#  TaggedDocument(words='nan', tags=[275]),
#  TaggedDocument(words='nan', tags=[276]),
#  TaggedDocument(words='nan', tags=[277]),
#  TaggedDocument(words='nan', tags=[278]),
#  TaggedDocument(words='nan', tags=[279]),
#  TaggedDocument(words='nan', tags=[280]),
#  TaggedDocument(words='nan', tags=[281]),
#  TaggedDocument(words="welcome to mobile wach neo! good job coming in for your visit! you will receive weekly sms to help support you during pregnancy and during the first months of your baby's life. please sms back and tell us any questions or concerns you have.", tags=[282]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. sometimes problems arise during labour and delivery, like bleeding or fits, which require skilled health workers, medications and equipment to treat. without that treatment, the mother and baby could die. therefore it is safest to deliver in a facility that can manage these and other problems. how will you arrive at the facility?', tags=[283]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}
),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic}. have you had your baby? we are here for you. please let us know as soon as you deliver so we can assist you after the baby arrives.', tags=[954]),
#  TaggedDocument(words='{name}, this is {nurse} from {clinic} bad swelling of hands and face or a bad headache are signs of a problem. ask your family to take you to the clinic if they see this. have you had any swelling or headaches during pregnancy? are they getting worse?', tags=[955]),
#  TaggedDocument(words='nan', tags=[956]),
#  TaggedDocument(words='nan', tags=[957]),
#  TaggedDocument(words='nan', tags=[958]),
#  TaggedDocument(words='nan', tags=[959]),
#  TaggedDocument(words='nan', tags=[960]),
#  TaggedDocument(words='nan', tags=[961]),
#  TaggedDocument(words='nan', tags=[962]),
#  TaggedDocument(words='nan', tags=[963]),
#  TaggedDocument(words='nan', tags=[964]),
#  TaggedDocument(words='nan', tags=[965]),
#  TaggedDocument(words='nan', tags=[966]),
#  TaggedDocument(words='nan', tags=[967]),
#  TaggedDocument(words='nan', tags=[968]),
#  TaggedDocument(words='nan', tags=[969]),
#  TaggedDocument(words='nan', tags=[970]),
#  TaggedDocument(words='nan', tags=[971]),
#  TaggedDocument(words='nan', tags=[972]),
#  TaggedDocument(words='nan', tags=[973]),
#  TaggedDocument(words='nan', tags=[974]),
#  TaggedDocument(words='nan', tags=[975]),
#  TaggedDocument(words='nan', tags=[976]),
#  TaggedDocument(words='nan', tags=[977]),
#  TaggedDocument(words='nan', tags=[978]),
#  TaggedDocument(words='nan', tags=[979]),
#  TaggedDocument(words='nan', tags=[980]),
#  TaggedDocument(words='nan', tags=[981]),
#  TaggedDocument(words='nan', tags=[982]),
#  TaggedDocument(words='nan', tags=[983]),
#  TaggedDocument(words='nan', tags=[984]),
#  TaggedDocument(words='nan', tags=[985]),
#  TaggedDocument(words='nan', tags=[986]),
#  TaggedDocument(words='nan', tags=[987]),
#  TaggedDocument(words='nan', tags=[988]),
#  TaggedDocument(words='nan', tags=[989]),
#  TaggedDocument(words='nan', tags=[990]),
#  TaggedDocument(words='nan', tags=[991]),
#  TaggedDocument(words='nan', tags=[992]),
#  TaggedDocument(words='nan', tags=[993]),
#  TaggedDocument(words='nan', tags=[994]),
#  TaggedDocument(words='nan', tags=[995]),
#  TaggedDocument(words='nan', tags=[996]),
#  TaggedDocument(words='nan', tags=[997]),
#  TaggedDocument(words='nan', tags=[998]),
#  TaggedDocument(words='nan', tags=[999]),
#  ...]

# %%
# max_epochs = 100
# vec_size = 20
# alpha = 0.025

# model = Doc2Vec(size=vec_size,
#                 alpha=alpha, 
#                 min_alpha=0.00025,
#                 min_count=1,
#                 dm =1)
  
# model.build_vocab(tagged_data)

# for epoch in range(max_epochs):
#     print('iteration {0}'.format(epoch))
#     model.train(tagged_data,
#                 total_examples=model.corpus_count,
#                 epochs=model.iter)
#     # decrease the learning rate
#     model.alpha -= 0.0002
#     # fix the learning rate, no decay
#     model.min_alpha = model.alpha

# model.save("d2v.model")
# print("Model Saved")

# %%
# %%time
model = Doc2Vec(documents, vector_size=10, window=5, min_count=1, workers=4, max_epochs = 100)
# Out:
# CPU times: user 16.7 s, sys: 2.86 s, total: 19.6 s
# Wall time: 12.9 s

# %%
vector = model.infer_vector([X_text[1]])
vector
# Out:
# array([ 0.03299328, -0.00578008, -0.01844985,  0.02667844, -0.03903807,
#         0.00983573,  0.00802733, -0.0303094 , -0.03605995,  0.00299558],
#       dtype=float32)

# %%
# to find most similar doc using tags
similar_doc = model.docvecs.most_similar(1)
print(similar_doc)
# Out:
# [(6115, 0.9778258204460144), (11229, 0.9757372140884399), (20586, 0.9691376090049744), (11594, 0.9684028625488281), (20188, 0.9682973027229309), (22198, 0.9645407199859619), (23980, 0.9645330905914307), (10953, 0.9607409238815308), (24022, 0.9600452780723572), (16970, 0.9589449763298035)]

# %%
print(X_text[1]) # original doc
# Out:
# Welcome to Mobile WACh NEO! Good job coming in for your visit! You will receive weekly SMS to help support you during pregnancy and during the first months of your baby's life. Please SMS back and tell us any questions or concerns you have.

# %%
# look at a similar doc
for d in similar_doc:
    i_sim = d[0]
    print(X_text[i_sim])
    print()
# Out:
# {name}, this is {nurse} from {clinic}. Babies normally poo once per day but some go more often. If your baby is going less than three times per week and is fussy they may need some help. Are you having any concerns?
#
# {name}, this is {nurse} from {clinic}. Babies normally poo once per day but some go more often. If your baby is going less than three times per week and is fussy they may need some help. Are you having any concerns?
#
# {name}, this is {nurse} from {clinic} Bad swelling of hands and face or a bad headache are signs of a problem. Ask your family to take you to the clinic if they see this. Have you had any swelling or headaches during pregnancy? Are they getting worse?
#
# {name}, this is {nurse} from {clinic}. It is safest for all women to deliver in a health facility because health workers have the skills and equipment needed to help ensure a safe delivery and a healthy baby. Where do you plan to deliver?
#
# {name}, this is {nurse} from {clinic}. Babies normally poo once per day but some go more often. If your baby is going less than three times per week and is fussy they may need some help. Are you having any concerns?
#
# {name}, this is {nurse} from {clinic}. This week our messages will be stopping. Please come in for your final visit with us when your baby is about 14 weeks old. Let us know if you have any difficulty coming in. We would like to know your experience with us and if this service has been helpful. We look forward to seeing you.
#
# {name}, this is {nurse} from {clinic}. Your baby may be trying to hold up their head. Spend a few minutes each day playing while they lay on their stomach. This will help them develop muscles they need to start crawling. Work up to 15 minutes a day. Do you have any questions about your baby's development?
#
# nan
#
# {name}, this is {nurse} from {clinic}. Your baby has two soft places on their head (fontanelles) where the skull bones haven't yet fused together. This was nature's way of allowing their head to pass through the birth canal . If the fontanelle becomes sunken it can be a sign of dehydration. They may also bulge slightly if the baby is crying, but it should return to normal when they stop – if not, see a doctor or nurse. Have you noticed these?
#
# {name}, this is {nurse} from {clinic}. Have you had your baby? We are here for you. Please let us know as soon as you deliver so we can assist you after the baby arrives.

# %%
# to find vector of doc in training data using tags or in other words, printing the vector of document at index 1 in training data
print(model.docvecs[1])
# Out:
# [-0.03171589  0.34602123 -0.06764278 -0.24734564 -0.00993758 -0.00089799
#   0.16393897  0.10734523 -0.04163233 -0.0514711 ]

# %%
len(model.docvecs)
# Out:
# 26021

# %%
# %%time

X_x = np.array([model.infer_vector([x_i]) for x_i in X_text])
print(X_x)
# Out:
# [[ 0.03299328 -0.00578008 -0.01844985 ... -0.0303094  -0.03605995
#    0.00299558]
#  [-0.04171736 -0.00604392 -0.04870269 ...  0.01028785 -0.03470396
#   -0.01463805]
#  [ 0.02605735 -0.02302002  0.01122474 ...  0.00362833  0.04224288
#   -0.04744409]
#  ...
#  [-0.00413358 -0.00241523  0.03917553 ... -0.01436976  0.00216582
#   -0.02774642]
#  [ 0.04283978  0.0426086   0.01604115 ...  0.03003889  0.04836584
#    0.0094691 ]
#  [ 0.02605735 -0.02302002  0.01122474 ...  0.00362833  0.04224288
#   -0.04744409]]
# CPU times: user 3.16 s, sys: 4.7 ms, total: 3.16 s
# Wall time: 3.16 s

# %%
range(len(X_x))
# Out:
# range(0, 26021)

# %%
# make a train/test split for out-of-sample validation

import sklearn.model_selection
train, test = sklearn.model_selection.train_test_split(range(len(y)))

# %%
X_x[train]
# Out:
# array([[-0.01796459, -0.00013448,  0.02003591, ...,  0.03980808,
#          0.00774688, -0.0141242 ],
#        [ 0.04668527,  0.03681654,  0.03337789, ..., -0.02221468,
#         -0.01677614,  0.01557795],
#        [-0.00383549,  0.03318316,  0.03673665, ..., -0.02639916,
#         -0.04574421,  0.04673693],
#        ...,
#        [-0.00383549,  0.03318316,  0.03673665, ..., -0.02639916,
#         -0.04574421,  0.04673693],
#        [-0.00383549,  0.03318316,  0.03673665, ..., -0.02639916,
#         -0.04574421,  0.04673693],
#        [-0.00383549,  0.03318316,  0.03673665, ..., -0.02639916,
#         -0.04574421,  0.04673693]], dtype=float32)

# %%
#We now fit the model
logreg =  sklearn.ensemble.GradientBoostingClassifier() # sklearn.linear_model.LogisticRegression(solver='lbfgs', max_iter=570)
logreg.fit(X_x[train], y[train])
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=None,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
prediction =  logreg.predict(X_x[test])  # logreg.predict(X_x[test])
pr = logreg.predict_proba(X_x[test])           # logreg.predict_proba(X_x[test])
plt.hist(pr[:,0])
plt.xlabel('Predicted Probability')
plt.ylabel('Number of messages')
plt.axis(xmin=0, xmax=1)
plt.grid();

# %%
#Let's testing out the predictions
#1. accuracy_score
accuracy_score(y[test], prediction)
#logreg.score(X_test, y_test)
# Out:
# 0.5834614202274824

# %%
#Let's also do roc-auc-score
roc_auc_score(y[test], pr[:,1])
# Out:
# 0.5857961921006205

# %%
#K-Fold Validation
rkf = RepeatedKFold(n_splits=10, n_repeats=10, random_state=2652124)
accuracy = []
roc_auc = []
gb_model = sklearn.ensemble.GradientBoostingClassifier()
for train_index, test_index in rkf.split(X_x, y):
    #print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X_x[train_index], X_x[test_index]
    y_train, y_test = y[train_index], y[test_index]
    gb_model.fit(X_train, y_train)
    pred = gb_model.predict(X_test)
    accuracy.append(accuracy_score(y_test, pred))  #converting the preditions to 100%
    #roc_auc.append(roc_auc_score(y_test, pred)*100)
    
statistics.mean(accuracy)
